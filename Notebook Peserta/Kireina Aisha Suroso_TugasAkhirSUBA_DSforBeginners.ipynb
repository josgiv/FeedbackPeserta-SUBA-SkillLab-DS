# %% [markdown]
# ## **Import Library**

# %%
# Import library yang digunakan
import pandas as pd

# Eksekusi sintaks berikut untuk meng-custom tampilan
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# # **Ekstraksi Data**

# %%
# Google Drive file ID
file_id = '1MvZttuTu1xMGe8RQenmv8J2giGpvDmdA'

# Construct the direct download URL
download_url = f'https://drive.google.com/uc?id={file_id}'

# Read the CSV directly into a pandas DataFrame
df = pd.read_csv(download_url)

# Display the first 5 rows of the DataFrame
display(df)
# Out:
#          Name  Gender   Age Education Level Screen Time (hrs/day)  \
# 0       Aarav    Male  15.0         Class 8                   7.1
# 1       Meera  Female  25.0             MSc                   3.3
# 2      Ishaan    Male  20.0           BTech                   9.5
# 3      Aditya    Male  20.0              BA                  10.8
# 4       Anika  Female  17.0        Class 11                   2.8
# ...       ...     ...   ...             ...                   ...
# 1245   Vivaan    Male  21.0           BTech                   6.1
# 1246    Arjun    Male  15.0         Class 9                   5.5
# 1247    Aarav    Male  22.0             NaN                   5.5
# 1248   Ananya  Female  16.0        Class 10                  10.4
# 1249  Krishna    Male  24.0           MTech                   2.0
#
#       Sleep Duration (hrs)  Physical Activity (hrs/week) Stress Level  \
# 0                     8.90                          9.30       Medium
# 1                    -5.00                          0.20       Medium
# 2                   150.00                          6.20       Medium
# 3                     5.60                          5.50         High
# 4                     5.40                          3.10       Medium
# ...                    ...                           ...          ...
# 1245                  6.20                          4.00          Low
# 1246                  8.00                          6.90       Medium
# 1247                  4.40                         -5.00       Medium
# 1248                  8.00                          6.60         High
# 1249                  8.00                          8.10         High
#
#      Anxious Before Exams Academic Performance Change
# 0                      No                        Same
# 1                      No                        Same
# 2                      No                        Same
# 3                     Yes                        Same
# 4                     Yes                        Same
# ...                   ...                         ...
# 1245                  Yes                    Declined
# 1246                  Yes                        Same
# 1247                   No                    Declined
# 1248                   No                    Declined
# 1249                  Yes                        Same
#
# [1250 rows x 10 columns]

# %% [markdown]
# # **Informasi Umum pada Data**

# %%
# menampilkan informasi umum
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Name                          1240 non-null   object
#  1   Gender                        1239 non-null   object
#  2   Age                           1240 non-null   object
#  3   Education Level               1240 non-null   object
#  4   Screen Time (hrs/day)         1236 non-null   object
#  5   Sleep Duration (hrs)          1232 non-null   float64
#  6   Physical Activity (hrs/week)  1243 non-null   float64
#  7   Stress Level                  1238 non-null   object
#  8   Anxious Before Exams          1233 non-null   object
#  9   Academic Performance Change   1235 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 97.8+ KB

# %% [markdown]
# # **Analisa Univariate**

# %% [markdown]
# ## **Kolom Kategorik**

# %%
# Seleksi kolom dengan tipe object
kolom_kategorik = df.select_dtypes(include='object').columns

# Tampilkan frekuensinya
for col in kolom_kategorik:
    print(f'> Frekuensi \033[93m{col}\033[0m')
    print(f'  Terdapat {df[col].nunique(dropna = False)} data unik\n')
    display(df[col].value_counts(dropna = False).reset_index())
    print('\n')
# Out:
# > Frekuensi Name
#   Terdapat 31 data unik
#        Name  count
# 0   Shaurya     77
# 1     Kavya     68
# 2     Meera     66
# 3    Aadhya     66
# 4      Diya     64
# 5     Arjun     64
# 6     Anika     61
# 7   Krishna     61
# 8      Myra     60
# 9   Reyansh     60
# 10    Aarav     60
# 11   Aditya     59
# 12   Ishaan     56
# 13   Ananya     54
# 14     Riya     54
# 15      Sai     51
# 16      Ira     50
# 17   Saanvi     49
# 18   Vivaan     48
# 19   Vihaan     41
# 20      Sam     16
# 21    Kiran     11
# 22      NaN     10
# 23    Rishi      8
# 24     Yash      7
# 25     Tanu      7
# 26      Dee      7
# 27      Dev      6
# 28     Tara      3
# 29     Arya      3
# 30      Ish      3
# > Frekuensi Gender
#   Terdapat 4 data unik
#    Gender  count
# 0  Female    592
# 1    Male    578
# 2   Other     69
# 3     NaN     11
# > Frekuensi Age
#   Terdapat 17 data unik
#        Age  count
# 0     17.0    121
# 1     21.0    120
# 2     23.0    115
# 3     15.0    108
# 4     20.0    104
# 5     16.0    104
# 6     25.0     96
# 7     19.0     96
# 8     26.0     90
# 9     22.0     88
# 10    18.0     88
# 11    24.0     85
# 12     1.0     13
# 13     NaN     10
# 14   200.0      6
# 15   150.0      5
# 16  twenty      1
# > Frekuensi Education Level
#   Terdapat 12 data unik
#    Education Level  count
# 0              MSc    172
# 1            MTech    172
# 2               MA    164
# 3         Class 10    116
# 4         Class 11    115
# 5              BSc    105
# 6            BTech    104
# 7          Class 9    100
# 8               BA     78
# 9          Class 8     58
# 10        Class 12     56
# 11             NaN     10
# > Frekuensi Screen Time (hrs/day)
#   Terdapat 106 data unik
#     Screen Time (hrs/day)  count
# 0                     6.9     22
# 1                     4.8     21
# 2                     4.5     21
# 3                     6.3     20
# 4                     9.9     19
# ..                    ...    ...
# 101                  12.0      6
# 102                   6.5      6
# 103                   9.2      4
# 104                   8.5      4
# 105               unknown      1
#
# [106 rows x 2 columns]
# > Frekuensi Stress Level
#   Terdapat 4 data unik
#   Stress Level  count
# 0       Medium    625
# 1          Low    398
# 2         High    215
# 3          NaN     12
# > Frekuensi Anxious Before Exams
#   Terdapat 3 data unik
#   Anxious Before Exams  count
# 0                  Yes    634
# 1                   No    599
# 2                  NaN     17
# > Frekuensi Academic Performance Change
#   Terdapat 4 data unik
#   Academic Performance Change  count
# 0                        Same    486
# 1                    Improved    377
# 2                    Declined    372
# 3                         NaN     15

# %%
# Ubah string 'twenty' menjadi numerik pada kolom Age
df['Age'] = df['Age'].replace('twenty', 20)

# Konversi tipe datanya
df['Age'] = df['Age'] = pd.to_numeric(df['Age'], errors='coerce').astype(pd.Int64Dtype())

# %%
# Ubah string 'unknown' pada kolom Screen Time (hrs/day) menjadi None (kosong)
df['Screen Time (hrs/day)'] = df['Screen Time (hrs/day)'].replace('unknown', None)

# Konversi tipe datanya
df['Screen Time (hrs/day)'] = pd.to_numeric(df['Screen Time (hrs/day)'], errors='coerce').astype(pd.Float64Dtype())

# %% [markdown]
# ## **Kolom Numerik**

# %%
# Seleksi kolom dengan tipe numerik
df_numerik = df.select_dtypes(include='number').columns

# Tampilkan statistik deskriptifnya
display(df[df_numerik].describe().T)
# Out:
#                                count  mean   std   min   25%   50%   75%  \
# Age                          1240.00 21.53 15.43  1.00 17.00 20.00 23.00
# Screen Time (hrs/day)        1235.00  8.17 13.47 -5.00  4.40  6.90  9.50
# Sleep Duration (hrs)         1232.00  8.20 15.18 -5.00  5.10  6.50  7.80
# Physical Activity (hrs/week) 1243.00  7.03 16.19 -5.00  2.70  5.10  7.70
#
#                                 max
# Age                          200.00
# Screen Time (hrs/day)        150.00
# Sleep Duration (hrs)         150.00
# Physical Activity (hrs/week) 150.00

# %% [markdown]
# ## **Missing Value**

# %% [markdown]
# ### **Menghitung Missing Value**

# %%
# Tampilkan missing value pada data
display(df.isnull().sum())
# Out:
# Name                            10
# Gender                          11
# Age                             10
# Education Level                 10
# Screen Time (hrs/day)           15
# Sleep Duration (hrs)            18
# Physical Activity (hrs/week)     7
# Stress Level                    12
# Anxious Before Exams            17
# Academic Performance Change     15
# dtype: int64

# %% [markdown]
# ### **Handling Missing Value - Tipe Kategorik**

# %%
# Tampilkan ukuran awal
df.shape
# Out:
# (1250, 10)

# %%
# Hapus baris yang Academic Performance Change kosong
df = df.dropna(subset=['Academic Performance Change'])
df.shape
# Out:
# (1235, 10)

# %%
# Isi gender yang kosong dengan 'Other'
df['Gender'] = df['Gender'].fillna('Other')

# Isi Education Level, Stress Level dan Anxious Before Exams yang kosong dengan 'Unknown'
df['Education Level'] = df['Education Level'].fillna('Unknown')
df['Stress Level'] = df['Stress Level'].fillna('Unknown')
df['Anxious Before Exams'] = df['Anxious Before Exams'].fillna('Unknown')

# %% [markdown]
# ### **Handling Missing Value - Tipe Numerik**

# %%
# Isikan setiap missing value pada kolom numerik dengan median datanya
for col in df_numerik:
    median_data = df[col].median()
    df[col] = df[col].fillna(median_data)

# %%
# Periksa missing value
display(df.isnull().sum())
# Out:
# Name                            10
# Gender                           0
# Age                              0
# Education Level                  0
# Screen Time (hrs/day)            0
# Sleep Duration (hrs)             0
# Physical Activity (hrs/week)     0
# Stress Level                     0
# Anxious Before Exams             0
# Academic Performance Change      0
# dtype: int64

# %% [markdown]
# ## **Duplicated Data**

# %% [markdown]
# ### **Menghitung Duplikasi Data**

# %%
# Periksa ukuran data
df.shape
# Out:
# (1235, 10)

# %%
# Periksa duplikasi dan hitung
jumlah_data_duplikat = df.duplicated(keep = False).sum()

# Tampilkan data duplikat
print(f'Jumlah data duplikat : {jumlah_data_duplikat}')
# Out:
# Jumlah data duplikat : 342

# %% [markdown]
# ### **Hapus Duplikasi Data**

# %%
# Hapus duplikasi data
df = df.drop_duplicates()

#Periksa ukuran data setelah di drop
df.shape
# Out:
# (1056, 10)

# %% [markdown]
# ## **Outlier**

# %% [markdown]
# ### **Mengidentifikasi Outlier**

# %%
import plotly.express as px

def box_plot(series, column_name, color):
    # Buat horizontal box plot
    fig = px.box(
        series,
        orientation = 'h',
        color_discrete_sequence  = [color]
    )

    # Update layout and display the plot
    fig.update_layout(
        title = f'<b>Box Plot {column_name}</b>',
        yaxis = dict(
            title = '',
            showgrid = False,
            showline = False,
            showticklabels = False,
            zeroline = False,
        ),
        xaxis = dict(
            title = column_name,
            showgrid = False,
            showline = True,
            showticklabels = True,
            zeroline = False,
        )
    )

    fig.show()

# %%
for col in df_numerik:
    box_plot(df[col], col, '#B07AA1')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="82bff687-a8cc-4755-a580-8910faea5284" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82bff687-a8cc-4755-a580-8910faea5284")) {                    Plotly.newPlot(                        "82bff687-a8cc-4755-a580-8910faea5284",                        [{"alignmentgroup":"True","hovertemplate":"value=%{x}\u003cbr\u003evariable=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#B07AA1"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[15,25,20,20,17,23,22,25,20,20,15,23,150,23,22,21,25,18,16,18,20,20,19,15,17,26,24,24,18,17,18,16,19,20,18,20,18,22,25,21,23,20,16,23,15,200,21,21,21,24,20,19,20,23,19,19,16,16,22,16,15,25,15,18,22,20,20,15,21,18,23,17,25,15,25,18,22,21,15,15,24,17,16,21,19,150,19,26,23,26,25,20,23,17,22,20,17,17,19,15,16,23,18,22,26,21,16,24,23,21,17,15,20,20,23,16,16,18,20,17,21,24,24,26,18,17,18,23,23,21,22,26,19,17,23,1,25,17,17,16,26,18,23,15,23,16,16,18,24,18,26,23,22,16,15,20,24,26,25,24,18,18,15,24,26,15,21,17,26,15,21,19,23,20,15,24,19,24,23,15,23,15,24,16,18,17,22,15,22,25,25,19,15,23,16,15,19,26,20,22,20,26,26,20,20,25,20,22,21,16,21,18,23,17,19,20,1,17,23,25,15,26,23,26,26,20,20,19,22,25,23,23,15,26,21,20,22,21,20,16,21,15,23,15,17,16,15,17,19,16,25,15,16,22,24,16,16,25,15,25,18,26,15,25,19,15,15,16,17,19,18,16,26,20,24,16,23,26,23,15,15,18,25,20,26,20,15,22,18,1,23,22,20,26,24,23,23,19,17,18,19,18,17,26,18,24,18,16,19,26,17,21,26,19,21,24,22,26,20,18,20,21,20,17,22,19,23,25,22,20,15,22,15,25,21,18,21,22,20,17,24,19,24,20,15,22,22,20,15,19,22,26,16,17,21,17,18,15,25,16,23,25,24,18,23,22,22,24,20,16,18,25,19,19,15,24,24,16,19,19,21,21,25,24,15,24,15,24,26,18,23,24,23,22,17,21,18,15,23,19,19,20,26,15,22,25,17,19,26,22,21,25,17,17,21,23,21,23,24,24,19,16,15,20,26,24,17,17,22,23,25,15,26,19,26,15,22,22,15,15,25,24,26,23,21,21,22,25,15,24,24,25,16,18,16,22,25,19,24,26,21,17,26,21,26,16,18,20,23,22,15,25,19,15,20,22,16,25,18,19,23,20,24,22,16,17,19,24,16,22,21,16,20,24,24,23,26,20,15,24,26,19,24,22,23,23,19,22,25,200,17,26,17,25,16,16,22,20,18,26,21,21,20,200,17,22,18,22,19,21,23,200,15,23,15,19,24,18,18,17,16,22,26,26,16,19,19,150,25,24,1,17,21,25,17,21,22,19,26,21,18,23,16,22,18,21,16,24,18,17,15,26,20,21,24,25,23,19,22,25,23,21,21,21,15,21,25,18,18,20,22,21,16,22,20,18,16,23,17,15,21,20,21,25,24,26,15,21,18,16,26,21,26,20,23,20,25,17,26,21,17,18,24,17,23,19,16,15,26,19,23,20,22,26,20,150,17,25,21,1,24,17,20,20,19,16,26,23,17,25,18,21,15,19,16,20,16,26,15,22,17,19,25,22,21,16,19,15,17,16,25,18,16,16,25,26,20,23,19,15,25,24,21,17,16,17,26,17,15,24,19,20,23,22,18,20,22,16,21,20,17,16,18,16,17,1,17,17,25,23,19,18,15,23,23,26,26,19,17,16,17,25,17,23,17,19,15,25,21,19,19,15,17,16,17,20,15,23,21,200,19,26,15,24,20,18,24,17,20,24,15,19,22,22,26,16,18,20,16,21,15,21,16,21,25,23,16,21,24,22,16,25,16,24,21,25,15,23,23,17,23,15,20,26,18,19,26,25,21,15,18,22,22,15,25,25,19,15,26,24,16,19,26,20,20,19,26,24,21,23,19,24,21,19,15,16,17,21,17,21,24,25,23,24,20,26,25,22,23,17,19,21,23,15,20,18,20,17,21,16,20,25,20,22,22,25,16,1,24,15,22,25,15,26,20,26,22,18,24,21,25,23,17,17,25,24,17,21,18,25,23,16,25,23,19,200,1,23,23,21,21,23,19,25,21,23,20,21,26,22,24,25,26,16,21,19,19,15,15,21,19,18,24,16,17,17,25,150,19,23,25,20,18,15,18,17,17,16,19,21,18,19,25,26,23,17,23,17,23,17,24,20,16,18,19,17,15,17,19,17,26,15,22,16,25,24,17,15,20,21,15,22,20,21,22,23,20,16,16,23,17,21,16,20,17,26,18,22,19,16,22,20,20,19,22,25,19,26,25,21,19,23,22,17,26,20,15,20,23,15,17,22,15,20,26,16,18,16,23,18,17,23,17,1,22,17,20,1,25,1,15,26,15,17,19,16,16,24,21,17,20,25,23,17,21,1,26,20,21,25,21,18,25,16,15,21,17,21,20,18,23,19,20,25,23,25,24,1,18,15,20,18,22,15,22,24],"x0":" ","xaxis": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ac9445f7-5415-4ec7-b98c-7aece5bdc000" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac9445f7-5415-4ec7-b98c-7aece5bdc000")) {                    Plotly.newPlot(                        "ac9445f7-5415-4ec7-b98c-7aece5bdc000",                        [{"alignmentgroup":"True","hovertemplate":"value=%{x}\u003cbr\u003evariable=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#B07AA1"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[7.1,3.3,9.5,10.8,2.8,8.6,3.6,7.0,4.8,8.9,8.0,10.3,5.8,11.2,8.9,11.1,11.5,7.0,9.7,2.5,6.9,6.0,7.6,11.0,3.0,4.7,9.9,3.2,7.9,7.9,5.4,2.4,9.5,11.4,10.6,10.6,11.7,6.7,8.3,6.6,5.6,2.5,7.8,11.9,2.4,9.4,7.9,9.3,8.0,5.1,7.2,10.7,4.9,3.6,3.1,8.7,11.1,6.1,3.4,2.2,4.7,11.0,10.3,9.9,7.3,3.3,7.2,3.1,5.8,7.7,10.0,7.0,3.2,3.5,2.6,9.8,9.1,9.8,7.6,7.5,3.9,10.6,7.5,5.6,10.7,5.8,4.6,99.0,11.5,6.1,7.7,10.0,3.4,11.5,5.1,5.4,6.4,3.2,5.2,2.6,2.3,3.7,5.1,150.0,2.2,7.6,7.8,10.7,7.7,8.1,6.0,7.7,9.8,4.9,4.3,9.3,4.6,11.8,9.2,5.9,4.2,4.5,10.1,6.3,5.1,9.6,8.7,9.6,4.2,6.0,3.6,5.3,4.7,10.8,2.8,5.6,11.9,8.1,7.3,3.5,11.6,4.5,5.2,7.4,7.3,3.4,2.9,8.8,11.9,2.8,3.6,2.6,9.6,11.5,11.2,11.7,4.5,6.7,8.4,7.1,5.3,8.6,4.5,8.4,7.4,3.0,3.7,3.8,4.8,3.1,6.3,2.7,10.5,8.5,8.8,4.4,12.0,8.4,8.1,3.8,9.9,4.3,4.4,3.9,4.5,7.6,8.2,10.6,2.2,4.0,8.2,10.5,4.8,11.6,3.1,7.8,5.1,5.9,10.6,7.4,4.7,3.9,10.8,8.6,8.3,8.1,7.1,-5.0,8.4,7.1,8.2,11.9,10.2,8.2,9.5,5.9,4.7,7.8,2.3,99.0,7.3,4.6,8.1,10.3,3.9,2.4,9.5,2.4,4.4,6.9,10.7,10.8,7.7,4.4,7.3,6.3,10.2,11.7,11.9,2.4,2.5,3.5,4.3,3.1,7.2,9.8,4.3,5.8,7.1,9.7,2.7,5.5,7.5,3.0,2.2,3.2,3.3,11.0,11.0,7.5,99.0,-5.0,9.8,5.4,6.9,5.0,9.0,4.5,6.4,9.6,8.3,11.7,11.7,4.3,9.5,8.8,12.0,10.6,9.5,5.8,2.2,3.4,2.5,3.6,6.1,2.4,2.5,9.2,5.0,2.0,10.4,11.7,5.8,2.2,150.0,9.6,11.2,7.0,5.1,8.1,11.6,2.1,3.9,9.4,6.9,5.7,4.2,8.7,7.0,5.2,4.6,11.2,2.4,3.8,9.9,11.4,9.8,5.8,2.1,5.6,2.5,8.3,9.3,2.1,6.0,4.8,5.1,10.6,2.1,2.9,3.3,6.5,7.6,11.8,4.8,6.4,7.2,5.6,3.0,6.9,2.5,2.4,10.6,8.9,10.0,11.1,6.9,4.1,8.4,7.3,8.9,5.8,11.5,10.5,4.4,8.9,8.4,10.9,6.9,2.1,4.6,10.0,6.6,3.6,5.1,2.8,10.8,6.9,5.2,4.8,2.6,2.9,6.7,9.7,4.5,9.3,7.6,3.5,2.5,4.2,5.7,8.9,4.7,7.1,10.0,2.0,8.1,7.8,7.4,4.5,11.1,2.7,4.6,11.9,10.4,2.8,7.4,7.5,2.8,5.8,9.9,6.3,6.7,3.7,5.7,4.7,11.0,3.1,10.4,5.6,7.9,5.2,7.4,9.7,6.0,3.0,9.5,6.6,8.8,7.7,6.3,3.3,9.0,7.8,8.0,150.0,3.9,6.9,2.5,2.6,9.1,4.7,2.2,11.5,6.6,6.3,2.3,8.8,10.3,4.0,11.8,9.3,6.5,9.1,11.2,4.5,2.2,8.9,9.9,8.3,2.9,4.3,9.1,2.0,5.1,3.7,5.3,10.9,10.0,3.8,9.7,8.1,7.9,4.2,9.0,11.0,10.1,6.9,5.3,3.6,4.3,4.0,2.8,7.2,7.2,11.1,11.1,2.0,5.8,5.5,11.2,6.8,9.5,7.2,150.0,4.8,2.6,4.6,8.0,7.9,11.6,7.0,6.9,5.4,4.5,9.7,4.8,6.2,9.4,4.4,9.5,2.1,2.3,150.0,11.5,6.1,5.2,3.6,5.4,8.3,9.5,10.1,11.9,8.3,11.7,3.0,7.5,9.4,7.1,9.1,9.7,7.4,4.8,7.3,4.0,5.7,6.2,5.3,10.5,10.3,6.9,5.6,4.9,5.5,11.8,10.1,9.6,9.8,3.2,2.0,11.8,6.3,8.5,11.0,6.3,8.3,5.2,11.8,4.0,9.1,9.8,7.9,9.2,12.0,6.9,10.9,-5.0,2.8,8.0,9.5,5.7,7.3,7.8,99.0,9.8,9.6,6.9,8.2,2.7,4.4,8.1,3.2,9.2,7.4,3.8,9.9,4.8,9.7,9.0,9.5,4.5,7.0,11.0,8.7,9.9,10.3,4.9,10.6,8.8,7.0,6.5,9.8,9.6,11.6,4.4,4.4,5.7,9.9,10.6,9.5,3.8,3.3,7.6,6.9,11.0,6.9,7.8,4.5,4.3,2.4,6.1,2.2,11.2,150.0,3.2,7.6,150.0,8.6,8.2,11.8,9.7,8.2,7.4,5.2,3.9,10.9,10.2,8.4,6.5,9.1,5.4,5.1,6.9,5.5,6.2,3.1,2.5,5.0,3.5,10.7,9.3,9.1,9.3,2.0,7.7,6.3,9.7,10.9,3.0,7.5,3.1,7.8,8.8,2.7,6.9,4.1,5.2,11.6,9.5,10.8,3.1,4.0,10.5,10.6,3.6,6.8,2.1,11.4,11.4,2.2,2.3,4.1,11.1,9.4,6.9,10.8,10.4,7.1,6.7,6.1,6.2,11.0,99.0,3.5,8.1,8.2,11.4,3.9,11.6,2.3,5.7,2.9,6.9,11.2,8.3,11.4,5.3,5.8,8.7,11.4,11.8,-5.0,6.8,9.0,11.3,2.2,5.3,9.3,5.5,10.9,11.3,4.1,4.8,6.7,8.7,6.0,4.8,4.3,6.8,10.8,7.0,9.7,11.9,4.2,5.4,6.3,7.3,4.5,9.9,4.8,7.3,8.0,8.3,10.4,5.1,9.0,2.3,12.0,10.2,4.1,7.9,4.8,11.1,8.1,4.2,7.8,3.3,8.4,11.3,11.0,5.9,2.8,5.5,3.0,7.5,5.1 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d98b9d18-cfe2-4da5-a1e7-5a3b1533a19b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d98b9d18-cfe2-4da5-a1e7-5a3b1533a19b")) {                    Plotly.newPlot(                        "d98b9d18-cfe2-4da5-a1e7-5a3b1533a19b",                        [{"alignmentgroup":"True","hovertemplate":"value=%{x}\u003cbr\u003evariable=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#B07AA1"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[8.9,-5.0,150.0,5.6,5.4,8.4,6.6,4.7,5.0,8.4,7.3,8.8,4.4,4.3,7.8,8.5,5.6,4.8,7.2,7.9,5.4,7.3,7.7,8.5,4.3,6.8,7.9,8.2,4.7,4.9,4.6,8.5,150.0,8.8,8.6,6.4,8.6,6.5,7.6,8.3,8.1,4.7,6.9,5.1,6.6,6.2,6.8,7.3,8.5,5.4,7.8,7.2,5.1,6.4,8.5,9.0,7.0,5.6,5.0,4.5,6.1,5.6,8.5,8.0,8.8,8.1,6.0,5.6,7.3,7.2,6.7,4.1,7.8,5.5,8.7,4.7,6.6,4.9,8.3,6.4,5.0,4.6,7.5,7.2,6.8,6.8,99.0,5.0,5.4,5.3,4.1,8.2,4.3,6.5,6.7,5.5,4.0,6.2,4.6,5.0,7.5,8.5,6.4,7.2,6.4,7.8,4.9,4.6,7.7,6.6,4.2,4.7,7.7,5.5,5.0,5.4,7.7,6.8,6.1,5.7,4.8,7.2,7.9,4.6,8.4,5.3,8.5,7.5,4.4,6.6,7.8,8.5,4.6,7.3,6.5,6.7,9.0,4.8,6.8,4.5,8.7,7.1,7.1,7.1,8.9,5.3,5.3,8.0,6.5,4.1,5.1,5.8,5.8,6.1,7.7,4.8,6.1,5.2,4.2,5.1,7.1,6.3,6.8,5.6,6.6,9.0,4.8,5.1,7.1,6.5,8.6,7.6,7.2,6.1,7.5,6.7,7.8,4.2,5.1,8.3,8.9,8.8,5.3,4.4,5.7,8.0,8.9,8.3,7.0,8.9,8.0,8.5,5.7,4.8,4.4,8.8,8.7,5.8,7.3,5.5,5.7,6.2,8.9,8.9,8.5,6.5,4.6,7.1,5.4,7.4,8.2,7.0,7.1,8.2,4.2,8.8,4.4,8.8,7.5,4.5,6.5,6.8,99.0,6.1,8.6,7.4,4.7,4.9,8.5,99.0,7.8,7.8,6.2,4.8,4.8,8.4,8.1,5.7,8.0,7.8,7.4,4.7,7.0,7.6,7.6,4.3,7.5,7.7,6.6,8.4,4.4,8.0,4.9,8.2,150.0,8.5,4.9,8.1,4.4,4.4,4.4,6.9,6.2,5.9,6.1,6.4,4.8,6.5,7.9,6.3,8.4,7.1,7.2,4.1,8.9,5.4,8.5,-5.0,8.2,6.4,5.6,8.7,4.3,6.8,4.2,5.3,5.1,6.4,6.5,4.1,6.1,6.5,7.8,8.4,5.0,5.2,4.0,4.6,8.5,6.8,6.3,8.3,6.0,5.9,5.0,7.0,7.6,8.3,4.5,7.8,8.7,5.4,7.5,5.3,8.2,7.2,8.3,4.8,7.9,4.5,5.7,99.0,4.1,7.8,6.4,5.5,5.2,6.9,8.3,8.1,6.8,6.8,5.4,4.2,6.8,4.6,5.8,5.2,4.8,8.0,8.8,4.6,7.4,8.6,8.3,6.7,6.5,7.1,5.8,5.9,4.4,6.9,-5.0,8.4,6.3,7.0,8.0,5.1,4.9,6.1,6.6,8.0,6.3,6.6,4.2,4.6,6.6,5.0,6.0,7.3,5.8,4.6,5.2,6.7,4.3,6.9,7.5,6.0,8.2,7.3,4.0,6.1,7.4,6.1,6.2,5.1,8.0,8.6,6.5,8.9,7.1,5.0,6.6,8.8,5.6,4.8,5.2,5.2,7.2,5.4,6.3,5.6,7.0,99.0,4.1,5.6,5.1,99.0,5.9,6.0,4.1,5.5,7.5,7.7,7.2,5.6,4.4,5.6,5.5,7.0,6.0,8.5,7.3,8.3,6.2,8.0,7.6,6.7,4.3,5.9,4.1,6.8,7.0,4.4,6.3,5.5,4.4,8.9,5.9,6.3,6.2,7.5,6.4,5.7,8.8,8.7,6.5,8.8,4.1,5.5,7.1,6.7,5.1,5.7,6.9,7.1,150.0,4.5,5.7,5.9,7.0,4.1,6.9,4.3,5.6,8.5,5.1,8.4,6.5,5.6,7.5,6.6,7.4,8.2,6.4,7.6,8.4,8.8,6.8,4.6,8.2,5.2,8.6,8.2,8.9,8.2,6.7,6.3,4.3,7.0,6.2,5.3,4.2,7.0,8.4,7.8,7.5,6.4,5.6,5.3,6.6,6.7,8.0,4.4,6.9,8.4,6.8,4.6,5.1,4.2,5.7,4.9,5.3,6.5,6.7,4.5,5.3,4.0,5.9,7.1,4.2,5.8,99.0,9.0,8.3,4.9,4.3,5.8,4.7,8.0,7.5,8.8,5.2,8.2,8.7,6.7,6.1,8.2,7.9,5.8,6.6,5.9,5.0,-5.0,7.8,7.9,7.2,8.6,8.0,4.0,-5.0,5.6,8.9,7.6,7.1,5.4,6.7,6.0,8.0,7.9,6.5,5.6,6.3,4.1,7.9,4.1,5.4,6.8,6.1,5.5,6.4,7.9,4.9,4.3,4.0,6.5,5.8,6.9,6.6,6.7,8.9,7.6,8.3,8.9,7.9,4.9,6.1,150.0,4.7,4.0,5.1,8.2,5.0,7.3,7.8,4.8,5.8,5.7,4.4,4.9,8.6,7.1,7.4,5.8,4.7,6.2,4.2,6.4,5.9,-5.0,5.5,7.4,8.5,6.8,6.5,6.1,4.4,6.9,6.9,4.4,4.5,5.6,4.6,7.3,4.8,8.7,7.0,6.8,8.9,5.4,8.1,5.4,5.1,5.9,5.6,5.2,8.9,5.2,4.7,4.3,8.1,4.6,6.5,7.2,4.0,5.6,7.5,5.6,5.8,6.0,6.5,4.7,8.9,7.6,8.8,7.1,7.6,4.3,7.5,6.5,6.5,7.0,4.4,6.3,5.2,8.8,5.5,6.3,7.7,7.9,8.3,4.3,7.6,4.2,6.8,7.1,4.1,6.0,5.3,6.1,4.6,7.4,7.7,8.4,7.9,5.1,6.6,5.1,5.7,8.2,6.4,8.2,7.9,8.2,7.0,9.0,7.9,7.2,4.6,8.2,6.0,4.4,9.0,5.4,4.1,4.2,99.0,5.1,6.1,4.6,4.8,4.1,6.5,4.7,6.6,150.0,7.9,4.8,4.6,7.1,8.2,4.6,8.3,5.6,5.0,8.9,6.5,4.6,4.6,8.0,4.1,7.2,6.1,8.0,7.3,7.1,6.4,7.2,8.5,4.2,7.7,4.3,4.2,4.6,5.5,6.6,7.6,6.2,8.5,6.1,4.9,8.7,4.4,8.9,5.9,8.6,4.8,7.4,6.7,8.8,8.9,6.5,9.0,150.0,4.6,4.3,6.1,5.3,6.4,6.4,8.6,7.2,9.0,8.3,4.6,8.2,4.9,5.4,8.1,7.9,8.9,8.1,8.8,7.0,4.7,6.7,6.9,7.5,8.0, ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="24759fe4-e9b9-4212-a720-6ef88517fcd4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24759fe4-e9b9-4212-a720-6ef88517fcd4")) {                    Plotly.newPlot(                        "24759fe4-e9b9-4212-a720-6ef88517fcd4",                        [{"alignmentgroup":"True","hovertemplate":"value=%{x}\u003cbr\u003evariable=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#B07AA1"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[9.3,0.2,6.2,5.5,3.1,0.1,0.5,4.5,7.9,7.8,0.8,3.7,6.7,1.4,5.3,2.1,0.4,9.9,1.5,2.8,6.8,3.9,2.7,1.9,8.6,9.6,0.7,0.9,1.6,3.2,8.4,8.7,1.1,7.4,8.8,8.2,6.8,6.8,6.8,7.6,5.5,1.1,2.0,3.0,5.4,5.1,9.6,3.0,99.0,5.7,6.8,8.1,5.1,1.0,2.6,0.4,9.2,1.6,8.5,150.0,6.8,4.4,0.3,7.8,4.0,9.4,5.1,6.0,9.9,3.0,2.2,2.3,8.8,1.7,9.1,2.6,1.7,9.4,0.0,4.7,5.8,5.9,4.8,7.6,2.8,2.9,3.6,0.6,0.9,9.3,6.3,9.9,0.1,3.3,1.1,6.8,8.5,0.2,5.8,4.9,5.9,5.1,3.5,7.4,0.1,8.2,2.6,0.8,5.5,1.9,5.9,8.0,6.3,4.7,8.9,5.8,1.0,6.7,0.3,7.5,5.4,3.2,3.9,3.3,2.8,0.9,4.1,6.4,4.9,5.8,6.2,8.3,8.4,6.5,6.2,3.6,0.8,8.9,4.2,8.5,4.4,2.3,3.1,3.1,3.8,8.4,0.2,1.4,7.4,8.5,0.4,6.0,5.7,150.0,3.2,9.3,0.5,9.5,1.7,0.7,3.0,6.1,5.1,2.3,5.8,1.2,0.3,2.9,9.2,4.1,0.3,99.0,4.6,8.0,9.9,99.0,2.0,1.4,150.0,3.0,2.3,9.7,2.3,6.6,2.8,3.2,1.2,3.5,4.5,4.2,8.1,5.7,1.5,4.8,0.7,8.3,7.2,6.0,8.5,3.4,9.4,0.1,0.1,2.7,1.2,9.1,0.6,9.4,5.1,9.7,6.1,9.6,5.2,4.2,6.8,0.9,9.9,9.3,9.9,6.3,3.6,0.3,6.7,0.2,3.5,9.9,7.3,3.2,2.1,8.9,5.1,8.7,6.7,8.2,3.0,3.1,3.2,8.7,8.3,5.9,4.8,3.9,0.2,5.8,2.5,1.9,0.3,6.4,8.6,6.2,4.7,6.9,4.3,5.2,6.8,6.3,9.6,7.6,7.0,0.8,8.1,7.7,6.5,6.4,7.2,5.5,6.0,7.8,0.0,0.7,9.5,3.7,3.8,8.4,8.0,9.9,5.9,7.6,8.6,1.8,5.8,2.6,3.6,7.1,4.5,0.6,1.0,2.0,9.4,0.1,7.7,9.6,7.6,8.9,6.6,-5.0,2.4,5.8,8.1,7.4,2.9,1.6,9.6,7.3,4.8,150.0,3.4,2.1,9.7,6.4,9.5,3.6,1.0,1.9,4.6,7.7,8.2,3.2,8.2,1.9,9.5,9.4,9.0,2.2,0.6,150.0,0.6,0.0,8.6,5.4,1.6,5.1,7.7,2.5,2.8,9.9,2.2,1.5,3.7,1.0,5.7,5.0,7.7,2.8,3.8,99.0,2.2,3.3,0.6,3.8,1.7,4.6,6.4,0.7,2.6,8.8,7.4,7.6,3.8,4.3,4.6,1.1,8.3,8.4,7.4,5.7,9.9,4.9,7.8,8.2,3.5,9.7,9.5,7.4,4.8,8.6,2.3,-5.0,3.0,2.8,6.7,2.9,0.1,2.6,2.2,6.8,0.4,10.0,6.5,6.2,8.8,1.1,3.3,5.2,4.3,150.0,3.1,9.4,8.1,9.3,3.8,1.7,5.0,2.7,9.8,3.9,1.1,7.2,99.0,3.8,6.9,5.8,9.6,9.0,0.3,6.7,6.2,6.0,2.2,3.2,9.1,4.0,7.9,3.2,5.3,8.1,10.0,4.6,0.8,2.2,3.9,9.5,7.9,1.1,2.6,7.3,2.9,3.8,6.6,3.9,1.6,2.9,8.6,6.9,2.7,1.3,8.9,6.3,8.6,2.8,2.9,5.5,5.0,7.7,7.7,3.5,1.3,1.3,1.5,2.8,1.4,8.9,2.4,8.9,3.3,99.0,8.4,99.0,1.9,4.1,7.9,3.5,1.7,3.6,7.2,6.0,9.6,6.8,4.4,8.0,4.8,1.5,4.4,9.3,6.0,1.9,7.6,1.6,9.8,3.8,5.7,6.3,8.5,8.3,6.4,3.2,4.7,7.8,-5.0,3.8,4.5,6.8,5.8,1.9,9.9,5.3,9.2,3.2,7.0,9.9,0.3,5.8,5.3,6.8,1.0,3.1,2.7,9.0,5.4,3.5,5.9,0.7,1.6,4.3,5.8,3.4,0.6,5.5,7.1,2.0,7.9,5.2,1.4,6.4,8.9,9.4,3.3,1.9,0.7,5.9,8.8,6.7,9.7,0.1,3.7,1.2,9.5,8.3,4.9,6.3,7.3,4.2,-5.0,0.6,5.1,6.1,1.6,0.2,8.9,8.8,3.5,4.4,1.6,7.0,2.4,8.3,-5.0,0.4,1.9,8.4,5.6,7.3,7.4,3.2,1.8,4.6,7.0,5.7,3.3,4.8,7.0,0.4,0.2,7.2,8.6,3.1,7.7,8.4,7.6,4.0,2.4,9.1,3.4,6.2,7.5,9.9,9.7,9.5,6.0,9.5,3.7,4.2,8.7,0.1,9.2,0.6,4.6,6.1,3.5,2.3,6.5,0.2,6.3,1.9,5.6,8.7,8.2,150.0,0.4,3.4,3.1,1.0,3.9,3.9,8.2,2.7,9.9,1.3,2.5,3.8,5.9,3.9,6.6,5.8,2.3,4.0,8.8,9.5,6.7,5.0,2.1,6.0,3.5,6.7,8.3,2.2,1.9,3.4,4.3,3.8,150.0,5.4,6.5,5.2,3.2,9.4,4.4,1.4,5.1,5.0,2.0,2.5,9.1,7.1,8.8,0.0,3.9,9.9,1.4,6.0,0.5,6.7,8.7,8.5,0.9,4.0,9.2,5.0,9.1,2.7,0.0,9.4,0.7,1.4,7.6,5.2,9.4,2.9,6.8,6.2,9.0,5.0,3.1,6.3,5.7,6.2,5.3,1.5,0.1,0.5,6.7,0.6,3.2,3.0,0.4,6.9,3.4,2.1,8.6,6.6,9.3,3.2,0.9,9.6,7.5,9.1,4.8,2.5,8.1,0.9,2.3,5.6,7.2,4.8,5.1,7.4,5.8,6.9,9.0,4.0,7.1,4.0,4.6,6.6,9.6,6.4,2.7,2.2,1.1,9.6,4.7,0.9,3.2,2.2,6.5,4.9,6.7,0.1,7.9,9.4,2.9,0.8,150.0,8.0,2.5,6.0,6.1,9.4,2.9,2.3,7.6,9.9,3.1,8.4,1.8,5.1,2.0,9.7,0.4,1.3,8.8,4.3,6.9,0.1,3.6,0.2,0.3,8.5,1.9,3.7,0.4,8.4,3.2,5.3,2.1,3.3,4.1,7.9, ...

# %% [markdown]
# ### **Mengatasi Outlier**

# %%
# Fungsi untuk teknik winsorizing
def teknik_winsorizing(series):
    # Hitung Q1, Q3, dan IQR
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1

    # Hitung lower dan upper bound
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Jika lower bound negatif maka ubah menjadi 0
    if(lower_bound < 0):
      lower_bound = 0

    # Winsorizing: clip nilai ke batas bawah & atas
    series = series.astype(pd.Float64Dtype())
    winsorized_series = series.clip(lower=lower_bound, upper=upper_bound)

    return (winsorized_series)

# %%
for col in df_numerik:
    df[col] = teknik_winsorizing(df[col])
    box_plot(df[col], col, '#B07AA1')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0ca3e3f4-0802-4e2b-9c50-b44d1f7da116" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ca3e3f4-0802-4e2b-9c50-b44d1f7da116")) {                    Plotly.newPlot(                        "0ca3e3f4-0802-4e2b-9c50-b44d1f7da116",                        [{"alignmentgroup":"True","hovertemplate":"value=%{x}\u003cbr\u003evariable=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#B07AA1"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[15.0,25.0,20.0,20.0,17.0,23.0,22.0,25.0,20.0,20.0,15.0,23.0,32.0,23.0,22.0,21.0,25.0,18.0,16.0,18.0,20.0,20.0,19.0,15.0,17.0,26.0,24.0,24.0,18.0,17.0,18.0,16.0,19.0,20.0,18.0,20.0,18.0,22.0,25.0,21.0,23.0,20.0,16.0,23.0,15.0,32.0,21.0,21.0,21.0,24.0,20.0,19.0,20.0,23.0,19.0,19.0,16.0,16.0,22.0,16.0,15.0,25.0,15.0,18.0,22.0,20.0,20.0,15.0,21.0,18.0,23.0,17.0,25.0,15.0,25.0,18.0,22.0,21.0,15.0,15.0,24.0,17.0,16.0,21.0,19.0,32.0,19.0,26.0,23.0,26.0,25.0,20.0,23.0,17.0,22.0,20.0,17.0,17.0,19.0,15.0,16.0,23.0,18.0,22.0,26.0,21.0,16.0,24.0,23.0,21.0,17.0,15.0,20.0,20.0,23.0,16.0,16.0,18.0,20.0,17.0,21.0,24.0,24.0,26.0,18.0,17.0,18.0,23.0,23.0,21.0,22.0,26.0,19.0,17.0,23.0,8.0,25.0,17.0,17.0,16.0,26.0,18.0,23.0,15.0,23.0,16.0,16.0,18.0,24.0,18.0,26.0,23.0,22.0,16.0,15.0,20.0,24.0,26.0,25.0,24.0,18.0,18.0,15.0,24.0,26.0,15.0,21.0,17.0,26.0,15.0,21.0,19.0,23.0,20.0,15.0,24.0,19.0,24.0,23.0,15.0,23.0,15.0,24.0,16.0,18.0,17.0,22.0,15.0,22.0,25.0,25.0,19.0,15.0,23.0,16.0,15.0,19.0,26.0,20.0,22.0,20.0,26.0,26.0,20.0,20.0,25.0,20.0,22.0,21.0,16.0,21.0,18.0,23.0,17.0,19.0,20.0,8.0,17.0,23.0,25.0,15.0,26.0,23.0,26.0,26.0,20.0,20.0,19.0,22.0,25.0,23.0,23.0,15.0,26.0,21.0,20.0,22.0,21.0,20.0,16.0,21.0,15.0,23.0,15.0,17.0,16.0,15.0,17.0,19.0,16.0,25.0,15.0,16.0,22.0,24.0,16.0,16.0,25.0,15.0,25.0,18.0,26.0,15.0,25.0,19.0,15.0,15.0,16.0,17.0,19.0,18.0,16.0,26.0,20.0,24.0,16.0,23.0,26.0,23.0,15.0,15.0,18.0,25.0,20.0,26.0,20.0,15.0,22.0,18.0,8.0,23.0,22.0,20.0,26.0,24.0,23.0,23.0,19.0,17.0,18.0,19.0,18.0,17.0,26.0,18.0,24.0,18.0,16.0,19.0,26.0,17.0,21.0,26.0,19.0,21.0,24.0,22.0,26.0,20.0,18.0,20.0,21.0,20.0,17.0,22.0,19.0,23.0,25.0,22.0,20.0,15.0,22.0,15.0,25.0,21.0,18.0,21.0,22.0,20.0,17.0,24.0,19.0,24.0,20.0,15.0,22.0,22.0,20.0,15.0,19.0,22.0,26.0,16.0,17.0,21.0,17.0,18.0,15.0,25.0,16.0,23.0,25.0,24.0,18.0,23.0,22.0,22.0,24.0,20.0,16.0,18.0,25.0,19.0,19.0,15.0,24.0,24.0,16.0,19.0,19.0,21.0,21.0,25.0,24.0,15.0,24.0,15.0,24.0,26.0,18.0,23.0,24.0,23.0,22.0,17.0,21.0,18.0,15.0,23.0,19.0,19.0,20.0,26.0,15.0,22.0,25.0,17.0,19.0,26.0,22.0,21.0,25.0,17.0,17.0,21.0,23.0,21.0,23.0,24.0,24.0,19.0,16.0,15.0,20.0,26.0,24.0,17.0,17.0,22.0,23.0,25.0,15.0,26.0,19.0,26.0,15.0,22.0,22.0,15.0,15.0,25.0,24.0,26.0,23.0,21.0,21.0,22.0,25.0,15.0,24.0,24.0,25.0,16.0,18.0,16.0,22.0,25.0,19.0,24.0,26.0,21.0,17.0,26.0,21.0,26.0,16.0,18.0,20.0,23.0,22.0,15.0,25.0,19.0,15.0,20.0,22.0,16.0,25.0,18.0,19.0,23.0,20.0,24.0,22.0,16.0,17.0,19.0,24.0,16.0,22.0,21.0,16.0,20.0,24.0,24.0,23.0,26.0,20.0,15.0,24.0,26.0,19.0,24.0,22.0,23.0,23.0,19.0,22.0,25.0,32.0,17.0,26.0,17.0,25.0,16.0,16.0,22.0,20.0,18.0,26.0,21.0,21.0,20.0,32.0,17.0,22.0,18.0,22.0,19.0,21.0,23.0,32.0,15.0,23.0,15.0,19.0,24.0,18.0,18.0,17.0,16.0,22.0,26.0,26.0,16.0,19.0,19.0,32.0,25.0,24.0,8.0,17.0,21.0,25.0,17.0,21.0,22.0,19.0,26.0,21.0,18.0,23.0,16.0,22.0,18.0,21.0,16.0,24.0,18.0,17.0,15.0,26.0,20.0,21.0,24.0,25.0,23.0,19.0,22.0,25.0,23.0,21.0,21.0,21.0,15.0,21.0,25.0,18.0,18.0,20.0,22.0,21.0,16.0,22.0,20.0,18.0,16.0,23.0,17.0,15.0,21.0,20.0,21.0,25.0,24.0,26.0,15.0,21.0,18.0,16.0,26.0,21.0,26.0,20.0,23.0,20.0,25.0,17.0,26.0,21.0,17.0,18.0,24.0,17.0,23.0,19.0,16.0,15.0,26.0,19.0,23.0,20.0,22.0,26.0,20.0,32.0,17.0,25. ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d0a92259-c69d-4439-8fd7-01407188f0e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0a92259-c69d-4439-8fd7-01407188f0e8")) {                    Plotly.newPlot(                        "d0a92259-c69d-4439-8fd7-01407188f0e8",                        [{"alignmentgroup":"True","hovertemplate":"value=%{x}\u003cbr\u003evariable=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#B07AA1"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[7.1,3.3,9.5,10.8,2.8,8.6,3.6,7.0,4.8,8.9,8.0,10.3,5.8,11.2,8.9,11.1,11.5,7.0,9.7,2.5,6.9,6.0,7.6,11.0,3.0,4.7,9.9,3.2,7.9,7.9,5.4,2.4,9.5,11.4,10.6,10.6,11.7,6.7,8.3,6.6,5.6,2.5,7.8,11.9,2.4,9.4,7.9,9.3,8.0,5.1,7.2,10.7,4.9,3.6,3.1,8.7,11.1,6.1,3.4,2.2,4.7,11.0,10.3,9.9,7.3,3.3,7.2,3.1,5.8,7.7,10.0,7.0,3.2,3.5,2.6,9.8,9.1,9.8,7.6,7.5,3.9,10.6,7.5,5.6,10.7,5.8,4.6,17.0,11.5,6.1,7.7,10.0,3.4,11.5,5.1,5.4,6.4,3.2,5.2,2.6,2.3,3.7,5.1,17.0,2.2,7.6,7.8,10.7,7.7,8.1,6.0,7.7,9.8,4.9,4.3,9.3,4.6,11.8,9.2,5.9,4.2,4.5,10.1,6.3,5.1,9.6,8.7,9.6,4.2,6.0,3.6,5.3,4.7,10.8,2.8,5.6,11.9,8.1,7.3,3.5,11.6,4.5,5.2,7.4,7.3,3.4,2.9,8.8,11.9,2.8,3.6,2.6,9.6,11.5,11.2,11.7,4.5,6.7,8.4,7.1,5.3,8.6,4.5,8.4,7.4,3.0,3.7,3.8,4.8,3.1,6.3,2.7,10.5,8.5,8.8,4.4,12.0,8.4,8.1,3.8,9.9,4.3,4.4,3.9,4.5,7.6,8.2,10.6,2.2,4.0,8.2,10.5,4.8,11.6,3.1,7.8,5.1,5.9,10.6,7.4,4.7,3.9,10.8,8.6,8.3,8.1,7.1,0.0,8.4,7.1,8.2,11.9,10.2,8.2,9.5,5.9,4.7,7.8,2.3,17.0,7.3,4.6,8.1,10.3,3.9,2.4,9.5,2.4,4.4,6.9,10.7,10.8,7.7,4.4,7.3,6.3,10.2,11.7,11.9,2.4,2.5,3.5,4.3,3.1,7.2,9.8,4.3,5.8,7.1,9.7,2.7,5.5,7.5,3.0,2.2,3.2,3.3,11.0,11.0,7.5,17.0,0.0,9.8,5.4,6.9,5.0,9.0,4.5,6.4,9.6,8.3,11.7,11.7,4.3,9.5,8.8,12.0,10.6,9.5,5.8,2.2,3.4,2.5,3.6,6.1,2.4,2.5,9.2,5.0,2.0,10.4,11.7,5.8,2.2,17.0,9.6,11.2,7.0,5.1,8.1,11.6,2.1,3.9,9.4,6.9,5.7,4.2,8.7,7.0,5.2,4.6,11.2,2.4,3.8,9.9,11.4,9.8,5.8,2.1,5.6,2.5,8.3,9.3,2.1,6.0,4.8,5.1,10.6,2.1,2.9,3.3,6.5,7.6,11.8,4.8,6.4,7.2,5.6,3.0,6.9,2.5,2.4,10.6,8.9,10.0,11.1,6.9,4.1,8.4,7.3,8.9,5.8,11.5,10.5,4.4,8.9,8.4,10.9,6.9,2.1,4.6,10.0,6.6,3.6,5.1,2.8,10.8,6.9,5.2,4.8,2.6,2.9,6.7,9.7,4.5,9.3,7.6,3.5,2.5,4.2,5.7,8.9,4.7,7.1,10.0,2.0,8.1,7.8,7.4,4.5,11.1,2.7,4.6,11.9,10.4,2.8,7.4,7.5,2.8,5.8,9.9,6.3,6.7,3.7,5.7,4.7,11.0,3.1,10.4,5.6,7.9,5.2,7.4,9.7,6.0,3.0,9.5,6.6,8.8,7.7,6.3,3.3,9.0,7.8,8.0,17.0,3.9,6.9,2.5,2.6,9.1,4.7,2.2,11.5,6.6,6.3,2.3,8.8,10.3,4.0,11.8,9.3,6.5,9.1,11.2,4.5,2.2,8.9,9.9,8.3,2.9,4.3,9.1,2.0,5.1,3.7,5.3,10.9,10.0,3.8,9.7,8.1,7.9,4.2,9.0,11.0,10.1,6.9,5.3,3.6,4.3,4.0,2.8,7.2,7.2,11.1,11.1,2.0,5.8,5.5,11.2,6.8,9.5,7.2,17.0,4.8,2.6,4.6,8.0,7.9,11.6,7.0,6.9,5.4,4.5,9.7,4.8,6.2,9.4,4.4,9.5,2.1,2.3,17.0,11.5,6.1,5.2,3.6,5.4,8.3,9.5,10.1,11.9,8.3,11.7,3.0,7.5,9.4,7.1,9.1,9.7,7.4,4.8,7.3,4.0,5.7,6.2,5.3,10.5,10.3,6.9,5.6,4.9,5.5,11.8,10.1,9.6,9.8,3.2,2.0,11.8,6.3,8.5,11.0,6.3,8.3,5.2,11.8,4.0,9.1,9.8,7.9,9.2,12.0,6.9,10.9,0.0,2.8,8.0,9.5,5.7,7.3,7.8,17.0,9.8,9.6,6.9,8.2,2.7,4.4,8.1,3.2,9.2,7.4,3.8,9.9,4.8,9.7,9.0,9.5,4.5,7.0,11.0,8.7,9.9,10.3,4.9,10.6,8.8,7.0,6.5,9.8,9.6,11.6,4.4,4.4,5.7,9.9,10.6,9.5,3.8,3.3,7.6,6.9,11.0,6.9,7.8,4.5,4.3,2.4,6.1,2.2,11.2,17.0,3.2,7.6,17.0,8.6,8.2,11.8,9.7,8.2,7.4,5.2,3.9,10.9,10.2,8.4,6.5,9.1,5.4,5.1,6.9,5.5,6.2,3.1,2.5,5.0,3.5,10.7,9.3,9.1,9.3,2.0,7.7,6.3,9.7,10.9,3.0,7.5,3.1,7.8,8.8,2.7,6.9,4.1,5.2,11.6,9.5,10.8,3.1,4.0,10.5,10.6,3.6,6.8,2.1,11.4,11.4,2.2,2.3,4.1,11.1,9.4,6.9,10.8,10.4,7.1,6.7,6.1,6.2,11.0,17.0,3.5,8.1,8.2,11.4,3.9,11.6,2.3,5.7,2.9,6.9,11.2,8.3,11.4,5.3,5.8,8.7,11.4,11.8,0.0,6.8,9.0,11.3,2.2,5.3,9.3,5.5,10.9,11.3,4.1,4.8,6.7,8.7,6.0,4.8,4.3,6.8,10.8,7.0,9.7,11.9,4.2,5.4,6.3,7.3,4.5,9.9,4.8,7.3,8.0,8.3,10.4,5.1,9.0,2.3,12.0,10.2,4.1,7.9,4.8,11.1,8.1,4.2,7.8,3.3,8.4,11.3,11.0,5.9,2.8,5.5,3.0,7.5,5.1,5.6,9.5,2. ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="90fbba8b-1083-4ccf-849d-1517718c997c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90fbba8b-1083-4ccf-849d-1517718c997c")) {                    Plotly.newPlot(                        "90fbba8b-1083-4ccf-849d-1517718c997c",                        [{"alignmentgroup":"True","hovertemplate":"value=%{x}\u003cbr\u003evariable=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#B07AA1"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[8.9,1.3000000000000007,11.7,5.6,5.4,8.4,6.6,4.7,5.0,8.4,7.3,8.8,4.4,4.3,7.8,8.5,5.6,4.8,7.2,7.9,5.4,7.3,7.7,8.5,4.3,6.8,7.9,8.2,4.7,4.9,4.6,8.5,11.7,8.8,8.6,6.4,8.6,6.5,7.6,8.3,8.1,4.7,6.9,5.1,6.6,6.2,6.8,7.3,8.5,5.4,7.8,7.2,5.1,6.4,8.5,9.0,7.0,5.6,5.0,4.5,6.1,5.6,8.5,8.0,8.8,8.1,6.0,5.6,7.3,7.2,6.7,4.1,7.8,5.5,8.7,4.7,6.6,4.9,8.3,6.4,5.0,4.6,7.5,7.2,6.8,6.8,11.7,5.0,5.4,5.3,4.1,8.2,4.3,6.5,6.7,5.5,4.0,6.2,4.6,5.0,7.5,8.5,6.4,7.2,6.4,7.8,4.9,4.6,7.7,6.6,4.2,4.7,7.7,5.5,5.0,5.4,7.7,6.8,6.1,5.7,4.8,7.2,7.9,4.6,8.4,5.3,8.5,7.5,4.4,6.6,7.8,8.5,4.6,7.3,6.5,6.7,9.0,4.8,6.8,4.5,8.7,7.1,7.1,7.1,8.9,5.3,5.3,8.0,6.5,4.1,5.1,5.8,5.8,6.1,7.7,4.8,6.1,5.2,4.2,5.1,7.1,6.3,6.8,5.6,6.6,9.0,4.8,5.1,7.1,6.5,8.6,7.6,7.2,6.1,7.5,6.7,7.8,4.2,5.1,8.3,8.9,8.8,5.3,4.4,5.7,8.0,8.9,8.3,7.0,8.9,8.0,8.5,5.7,4.8,4.4,8.8,8.7,5.8,7.3,5.5,5.7,6.2,8.9,8.9,8.5,6.5,4.6,7.1,5.4,7.4,8.2,7.0,7.1,8.2,4.2,8.8,4.4,8.8,7.5,4.5,6.5,6.8,11.7,6.1,8.6,7.4,4.7,4.9,8.5,11.7,7.8,7.8,6.2,4.8,4.8,8.4,8.1,5.7,8.0,7.8,7.4,4.7,7.0,7.6,7.6,4.3,7.5,7.7,6.6,8.4,4.4,8.0,4.9,8.2,11.7,8.5,4.9,8.1,4.4,4.4,4.4,6.9,6.2,5.9,6.1,6.4,4.8,6.5,7.9,6.3,8.4,7.1,7.2,4.1,8.9,5.4,8.5,1.3000000000000007,8.2,6.4,5.6,8.7,4.3,6.8,4.2,5.3,5.1,6.4,6.5,4.1,6.1,6.5,7.8,8.4,5.0,5.2,4.0,4.6,8.5,6.8,6.3,8.3,6.0,5.9,5.0,7.0,7.6,8.3,4.5,7.8,8.7,5.4,7.5,5.3,8.2,7.2,8.3,4.8,7.9,4.5,5.7,11.7,4.1,7.8,6.4,5.5,5.2,6.9,8.3,8.1,6.8,6.8,5.4,4.2,6.8,4.6,5.8,5.2,4.8,8.0,8.8,4.6,7.4,8.6,8.3,6.7,6.5,7.1,5.8,5.9,4.4,6.9,1.3000000000000007,8.4,6.3,7.0,8.0,5.1,4.9,6.1,6.6,8.0,6.3,6.6,4.2,4.6,6.6,5.0,6.0,7.3,5.8,4.6,5.2,6.7,4.3,6.9,7.5,6.0,8.2,7.3,4.0,6.1,7.4,6.1,6.2,5.1,8.0,8.6,6.5,8.9,7.1,5.0,6.6,8.8,5.6,4.8,5.2,5.2,7.2,5.4,6.3,5.6,7.0,11.7,4.1,5.6,5.1,11.7,5.9,6.0,4.1,5.5,7.5,7.7,7.2,5.6,4.4,5.6,5.5,7.0,6.0,8.5,7.3,8.3,6.2,8.0,7.6,6.7,4.3,5.9,4.1,6.8,7.0,4.4,6.3,5.5,4.4,8.9,5.9,6.3,6.2,7.5,6.4,5.7,8.8,8.7,6.5,8.8,4.1,5.5,7.1,6.7,5.1,5.7,6.9,7.1,11.7,4.5,5.7,5.9,7.0,4.1,6.9,4.3,5.6,8.5,5.1,8.4,6.5,5.6,7.5,6.6,7.4,8.2,6.4,7.6,8.4,8.8,6.8,4.6,8.2,5.2,8.6,8.2,8.9,8.2,6.7,6.3,4.3,7.0,6.2,5.3,4.2,7.0,8.4,7.8,7.5,6.4,5.6,5.3,6.6,6.7,8.0,4.4,6.9,8.4,6.8,4.6,5.1,4.2,5.7,4.9,5.3,6.5,6.7,4.5,5.3,4.0,5.9,7.1,4.2,5.8,11.7,9.0,8.3,4.9,4.3,5.8,4.7,8.0,7.5,8.8,5.2,8.2,8.7,6.7,6.1,8.2,7.9,5.8,6.6,5.9,5.0,1.3000000000000007,7.8,7.9,7.2,8.6,8.0,4.0,1.3000000000000007,5.6,8.9,7.6,7.1,5.4,6.7,6.0,8.0,7.9,6.5,5.6,6.3,4.1,7.9,4.1,5.4,6.8,6.1,5.5,6.4,7.9,4.9,4.3,4.0,6.5,5.8,6.9,6.6,6.7,8.9,7.6,8.3,8.9,7.9,4.9,6.1,11.7,4.7,4.0,5.1,8.2,5.0,7.3,7.8,4.8,5.8,5.7,4.4,4.9,8.6,7.1,7.4,5.8,4.7,6.2,4.2,6.4,5.9,1.3000000000000007,5.5,7.4,8.5,6.8,6.5,6.1,4.4,6.9,6.9,4.4,4.5,5.6,4.6,7.3,4.8,8.7,7.0,6.8,8.9,5.4,8.1,5.4,5.1,5.9,5.6,5.2,8.9,5.2,4.7,4.3,8.1,4.6,6.5,7.2,4.0,5.6,7.5,5.6,5.8,6.0,6.5,4.7,8.9,7.6,8.8,7.1,7.6,4.3,7.5,6.5,6.5,7.0,4.4,6.3,5.2,8.8,5.5,6.3,7.7,7.9,8.3,4.3,7.6,4.2,6.8,7.1,4.1,6.0,5.3,6.1,4.6,7.4,7.7,8.4,7.9,5.1,6.6,5.1,5.7,8.2,6.4,8.2,7.9,8.2,7.0,9.0,7.9,7.2,4.6,8.2,6.0,4.4,9.0,5.4,4.1,4.2,11.7,5.1,6.1,4.6,4.8,4.1,6.5,4.7,6.6,11.7,7.9,4.8,4.6,7.1,8.2,4.6,8.3,5.6,5.0,8.9,6.5,4.6,4.6,8.0,4.1,7.2,6.1,8.0,7.3,7.1,6.4,7.2,8.5,4.2,7.7,4.3,4.2,4.6,5.5,6.6,7.6,6.2,8.5,6.1,4.9,8.7,4.4,8.9,5.9,8.6,4.8,7.4,6.7,8.8,8.9,6.5,9.0,11.7,4.6,4.3,6.1,5.3,6.4,6.4 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9fb393da-a9fe-48b1-afab-271dccc29ba9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fb393da-a9fe-48b1-afab-271dccc29ba9")) {                    Plotly.newPlot(                        "9fb393da-a9fe-48b1-afab-271dccc29ba9",                        [{"alignmentgroup":"True","hovertemplate":"value=%{x}\u003cbr\u003evariable=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#B07AA1"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[9.3,0.2,6.2,5.5,3.1,0.1,0.5,4.5,7.9,7.8,0.8,3.7,6.7,1.4,5.3,2.1,0.4,9.9,1.5,2.8,6.8,3.9,2.7,1.9,8.6,9.6,0.7,0.9,1.6,3.2,8.4,8.7,1.1,7.4,8.8,8.2,6.8,6.8,6.8,7.6,5.5,1.1,2.0,3.0,5.4,5.1,9.6,3.0,15.2,5.7,6.8,8.1,5.1,1.0,2.6,0.4,9.2,1.6,8.5,15.2,6.8,4.4,0.3,7.8,4.0,9.4,5.1,6.0,9.9,3.0,2.2,2.3,8.8,1.7,9.1,2.6,1.7,9.4,0.0,4.7,5.8,5.9,4.8,7.6,2.8,2.9,3.6,0.6,0.9,9.3,6.3,9.9,0.1,3.3,1.1,6.8,8.5,0.2,5.8,4.9,5.9,5.1,3.5,7.4,0.1,8.2,2.6,0.8,5.5,1.9,5.9,8.0,6.3,4.7,8.9,5.8,1.0,6.7,0.3,7.5,5.4,3.2,3.9,3.3,2.8,0.9,4.1,6.4,4.9,5.8,6.2,8.3,8.4,6.5,6.2,3.6,0.8,8.9,4.2,8.5,4.4,2.3,3.1,3.1,3.8,8.4,0.2,1.4,7.4,8.5,0.4,6.0,5.7,15.2,3.2,9.3,0.5,9.5,1.7,0.7,3.0,6.1,5.1,2.3,5.8,1.2,0.3,2.9,9.2,4.1,0.3,15.2,4.6,8.0,9.9,15.2,2.0,1.4,15.2,3.0,2.3,9.7,2.3,6.6,2.8,3.2,1.2,3.5,4.5,4.2,8.1,5.7,1.5,4.8,0.7,8.3,7.2,6.0,8.5,3.4,9.4,0.1,0.1,2.7,1.2,9.1,0.6,9.4,5.1,9.7,6.1,9.6,5.2,4.2,6.8,0.9,9.9,9.3,9.9,6.3,3.6,0.3,6.7,0.2,3.5,9.9,7.3,3.2,2.1,8.9,5.1,8.7,6.7,8.2,3.0,3.1,3.2,8.7,8.3,5.9,4.8,3.9,0.2,5.8,2.5,1.9,0.3,6.4,8.6,6.2,4.7,6.9,4.3,5.2,6.8,6.3,9.6,7.6,7.0,0.8,8.1,7.7,6.5,6.4,7.2,5.5,6.0,7.8,0.0,0.7,9.5,3.7,3.8,8.4,8.0,9.9,5.9,7.6,8.6,1.8,5.8,2.6,3.6,7.1,4.5,0.6,1.0,2.0,9.4,0.1,7.7,9.6,7.6,8.9,6.6,0.0,2.4,5.8,8.1,7.4,2.9,1.6,9.6,7.3,4.8,15.2,3.4,2.1,9.7,6.4,9.5,3.6,1.0,1.9,4.6,7.7,8.2,3.2,8.2,1.9,9.5,9.4,9.0,2.2,0.6,15.2,0.6,0.0,8.6,5.4,1.6,5.1,7.7,2.5,2.8,9.9,2.2,1.5,3.7,1.0,5.7,5.0,7.7,2.8,3.8,15.2,2.2,3.3,0.6,3.8,1.7,4.6,6.4,0.7,2.6,8.8,7.4,7.6,3.8,4.3,4.6,1.1,8.3,8.4,7.4,5.7,9.9,4.9,7.8,8.2,3.5,9.7,9.5,7.4,4.8,8.6,2.3,0.0,3.0,2.8,6.7,2.9,0.1,2.6,2.2,6.8,0.4,10.0,6.5,6.2,8.8,1.1,3.3,5.2,4.3,15.2,3.1,9.4,8.1,9.3,3.8,1.7,5.0,2.7,9.8,3.9,1.1,7.2,15.2,3.8,6.9,5.8,9.6,9.0,0.3,6.7,6.2,6.0,2.2,3.2,9.1,4.0,7.9,3.2,5.3,8.1,10.0,4.6,0.8,2.2,3.9,9.5,7.9,1.1,2.6,7.3,2.9,3.8,6.6,3.9,1.6,2.9,8.6,6.9,2.7,1.3,8.9,6.3,8.6,2.8,2.9,5.5,5.0,7.7,7.7,3.5,1.3,1.3,1.5,2.8,1.4,8.9,2.4,8.9,3.3,15.2,8.4,15.2,1.9,4.1,7.9,3.5,1.7,3.6,7.2,6.0,9.6,6.8,4.4,8.0,4.8,1.5,4.4,9.3,6.0,1.9,7.6,1.6,9.8,3.8,5.7,6.3,8.5,8.3,6.4,3.2,4.7,7.8,0.0,3.8,4.5,6.8,5.8,1.9,9.9,5.3,9.2,3.2,7.0,9.9,0.3,5.8,5.3,6.8,1.0,3.1,2.7,9.0,5.4,3.5,5.9,0.7,1.6,4.3,5.8,3.4,0.6,5.5,7.1,2.0,7.9,5.2,1.4,6.4,8.9,9.4,3.3,1.9,0.7,5.9,8.8,6.7,9.7,0.1,3.7,1.2,9.5,8.3,4.9,6.3,7.3,4.2,0.0,0.6,5.1,6.1,1.6,0.2,8.9,8.8,3.5,4.4,1.6,7.0,2.4,8.3,0.0,0.4,1.9,8.4,5.6,7.3,7.4,3.2,1.8,4.6,7.0,5.7,3.3,4.8,7.0,0.4,0.2,7.2,8.6,3.1,7.7,8.4,7.6,4.0,2.4,9.1,3.4,6.2,7.5,9.9,9.7,9.5,6.0,9.5,3.7,4.2,8.7,0.1,9.2,0.6,4.6,6.1,3.5,2.3,6.5,0.2,6.3,1.9,5.6,8.7,8.2,15.2,0.4,3.4,3.1,1.0,3.9,3.9,8.2,2.7,9.9,1.3,2.5,3.8,5.9,3.9,6.6,5.8,2.3,4.0,8.8,9.5,6.7,5.0,2.1,6.0,3.5,6.7,8.3,2.2,1.9,3.4,4.3,3.8,15.2,5.4,6.5,5.2,3.2,9.4,4.4,1.4,5.1,5.0,2.0,2.5,9.1,7.1,8.8,0.0,3.9,9.9,1.4,6.0,0.5,6.7,8.7,8.5,0.9,4.0,9.2,5.0,9.1,2.7,0.0,9.4,0.7,1.4,7.6,5.2,9.4,2.9,6.8,6.2,9.0,5.0,3.1,6.3,5.7,6.2,5.3,1.5,0.1,0.5,6.7,0.6,3.2,3.0,0.4,6.9,3.4,2.1,8.6,6.6,9.3,3.2,0.9,9.6,7.5,9.1,4.8,2.5,8.1,0.9,2.3,5.6,7.2,4.8,5.1,7.4,5.8,6.9,9.0,4.0,7.1,4.0,4.6,6.6,9.6,6.4,2.7,2.2,1.1,9.6,4.7,0.9,3.2,2.2,6.5,4.9,6.7,0.1,7.9,9.4,2.9,0.8,15.2,8.0,2.5,6.0,6.1,9.4,2.9,2.3,7.6,9.9,3.1,8.4,1.8,5.1,2.0,9.7,0.4,1.3,8.8,4.3,6.9,0.1,3.6,0.2,0.3,8.5,1.9,3.7,0.4,8.4,3.2,5.3,2.1,3.3,4.1,7.9,5.8,9.1,9.0,7. ...

# %% [markdown]
# ## **Distribusi**

# %%
import plotly.express as px

for col in df_numerik:
    fig = px.histogram(
        df,
        x = col,
        nbins = 25,
        color_discrete_sequence = ['#B07AA1'],
        marginal = "box",
        hover_data = df.columns
    )

    fig.update_yaxes(
        showgrid = False,
        showticklabels=False,
        title =''
    )

    fig.update_layout(
        title={
            'text' : f'Distribusi <b><span style="color:#B07AA1"></span> {col}</b>',
            'y':0.92,
            'x':0.5,
            'xanchor': 'center',
            'yanchor': 'top'
        },
        plot_bgcolor = 'rgba(0,0,0,0)',
        bargap = 0.01,
        title_font = dict(size = 25)
    )

    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dc4185f7-be97-45c1-8e27-8d3721260c72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc4185f7-be97-45c1-8e27-8d3721260c72")) {                    Plotly.newPlot(                        "dc4185f7-be97-45c1-8e27-8d3721260c72",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Age=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#B07AA1","pattern":{"shape":""}},"name":"","nbinsx":25,"offsetgroup":"","orientation":"v","showlegend":false,"x":[15.0,25.0,20.0,20.0,17.0,23.0,22.0,25.0,20.0,20.0,15.0,23.0,32.0,23.0,22.0,21.0,25.0,18.0,16.0,18.0,20.0,20.0,19.0,15.0,17.0,26.0,24.0,24.0,18.0,17.0,18.0,16.0,19.0,20.0,18.0,20.0,18.0,22.0,25.0,21.0,23.0,20.0,16.0,23.0,15.0,32.0,21.0,21.0,21.0,24.0,20.0,19.0,20.0,23.0,19.0,19.0,16.0,16.0,22.0,16.0,15.0,25.0,15.0,18.0,22.0,20.0,20.0,15.0,21.0,18.0,23.0,17.0,25.0,15.0,25.0,18.0,22.0,21.0,15.0,15.0,24.0,17.0,16.0,21.0,19.0,32.0,19.0,26.0,23.0,26.0,25.0,20.0,23.0,17.0,22.0,20.0,17.0,17.0,19.0,15.0,16.0,23.0,18.0,22.0,26.0,21.0,16.0,24.0,23.0,21.0,17.0,15.0,20.0,20.0,23.0,16.0,16.0,18.0,20.0,17.0,21.0,24.0,24.0,26.0,18.0,17.0,18.0,23.0,23.0,21.0,22.0,26.0,19.0,17.0,23.0,8.0,25.0,17.0,17.0,16.0,26.0,18.0,23.0,15.0,23.0,16.0,16.0,18.0,24.0,18.0,26.0,23.0,22.0,16.0,15.0,20.0,24.0,26.0,25.0,24.0,18.0,18.0,15.0,24.0,26.0,15.0,21.0,17.0,26.0,15.0,21.0,19.0,23.0,20.0,15.0,24.0,19.0,24.0,23.0,15.0,23.0,15.0,24.0,16.0,18.0,17.0,22.0,15.0,22.0,25.0,25.0,19.0,15.0,23.0,16.0,15.0,19.0,26.0,20.0,22.0,20.0,26.0,26.0,20.0,20.0,25.0,20.0,22.0,21.0,16.0,21.0,18.0,23.0,17.0,19.0,20.0,8.0,17.0,23.0,25.0,15.0,26.0,23.0,26.0,26.0,20.0,20.0,19.0,22.0,25.0,23.0,23.0,15.0,26.0,21.0,20.0,22.0,21.0,20.0,16.0,21.0,15.0,23.0,15.0,17.0,16.0,15.0,17.0,19.0,16.0,25.0,15.0,16.0,22.0,24.0,16.0,16.0,25.0,15.0,25.0,18.0,26.0,15.0,25.0,19.0,15.0,15.0,16.0,17.0,19.0,18.0,16.0,26.0,20.0,24.0,16.0,23.0,26.0,23.0,15.0,15.0,18.0,25.0,20.0,26.0,20.0,15.0,22.0,18.0,8.0,23.0,22.0,20.0,26.0,24.0,23.0,23.0,19.0,17.0,18.0,19.0,18.0,17.0,26.0,18.0,24.0,18.0,16.0,19.0,26.0,17.0,21.0,26.0,19.0,21.0,24.0,22.0,26.0,20.0,18.0,20.0,21.0,20.0,17.0,22.0,19.0,23.0,25.0,22.0,20.0,15.0,22.0,15.0,25.0,21.0,18.0,21.0,22.0,20.0,17.0,24.0,19.0,24.0,20.0,15.0,22.0,22.0,20.0,15.0,19.0,22.0,26.0,16.0,17.0,21.0,17.0,18.0,15.0,25.0,16.0,23.0,25.0,24.0,18.0,23.0,22.0,22.0,24.0,20.0,16.0,18.0,25.0,19.0,19.0,15.0,24.0,24.0,16.0,19.0,19.0,21.0,21.0,25.0,24.0,15.0,24.0,15.0,24.0,26.0,18.0,23.0,24.0,23.0,22.0,17.0,21.0,18.0,15.0,23.0,19.0,19.0,20.0,26.0,15.0,22.0,25.0,17.0,19.0,26.0,22.0,21.0,25.0,17.0,17.0,21.0,23.0,21.0,23.0,24.0,24.0,19.0,16.0,15.0,20.0,26.0,24.0,17.0,17.0,22.0,23.0,25.0,15.0,26.0,19.0,26.0,15.0,22.0,22.0,15.0,15.0,25.0,24.0,26.0,23.0,21.0,21.0,22.0,25.0,15.0,24.0,24.0,25.0,16.0,18.0,16.0,22.0,25.0,19.0,24.0,26.0,21.0,17.0,26.0,21.0,26.0,16.0,18.0,20.0,23.0,22.0,15.0,25.0,19.0,15.0,20.0,22.0,16.0,25.0,18.0,19.0,23.0,20.0,24.0,22.0,16.0,17.0,19.0,24.0,16.0,22.0,21.0,16.0,20.0,24.0,24.0,23.0,26.0,20.0,15.0,24.0,26.0,19.0,24.0,22.0,23.0,23.0,19.0,22.0,25.0,32.0,17.0,26.0,17.0,25.0,16.0,16.0,22.0,20.0,18.0,26.0,21.0,21.0,20.0,32.0,17.0,22.0,18.0,22.0,19.0,21.0,23.0,32.0,15.0,23.0,15.0,19.0,24.0,18.0,18.0,17.0,16.0,22.0,26.0,26.0,16.0,19.0,19.0,32.0,25.0,24.0,8.0,17.0,21.0,25.0,17.0,21.0,22.0,19.0,26.0,21.0,18.0,23.0,16.0,22.0,18.0,21.0,16.0,24.0,18.0,17.0,15.0,26.0,20.0,21.0,24.0,25.0,23.0,19.0,22.0,25.0,23.0,21.0,21.0,21.0,15.0,21.0,25.0,18.0,18.0,20.0,22.0,21.0,16.0,22.0,20.0,18.0,16.0,23.0,17.0,15.0,21.0,20.0,21.0,25.0,24.0,26.0,15.0,21.0,18.0,16.0,26.0,21.0,26.0,20.0,23.0,20.0,25.0,17.0,26.0,21.0,17.0,18.0,24.0,17.0,23.0,19.0,16.0,15.0,26.0,19.0,23.0,20.0 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a1d71e2f-bcb1-4fca-81c9-c0eaf7bbd4dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1d71e2f-bcb1-4fca-81c9-c0eaf7bbd4dc")) {                    Plotly.newPlot(                        "a1d71e2f-bcb1-4fca-81c9-c0eaf7bbd4dc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Screen Time (hrs\u002fday)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#B07AA1","pattern":{"shape":""}},"name":"","nbinsx":25,"offsetgroup":"","orientation":"v","showlegend":false,"x":[7.1,3.3,9.5,10.8,2.8,8.6,3.6,7.0,4.8,8.9,8.0,10.3,5.8,11.2,8.9,11.1,11.5,7.0,9.7,2.5,6.9,6.0,7.6,11.0,3.0,4.7,9.9,3.2,7.9,7.9,5.4,2.4,9.5,11.4,10.6,10.6,11.7,6.7,8.3,6.6,5.6,2.5,7.8,11.9,2.4,9.4,7.9,9.3,8.0,5.1,7.2,10.7,4.9,3.6,3.1,8.7,11.1,6.1,3.4,2.2,4.7,11.0,10.3,9.9,7.3,3.3,7.2,3.1,5.8,7.7,10.0,7.0,3.2,3.5,2.6,9.8,9.1,9.8,7.6,7.5,3.9,10.6,7.5,5.6,10.7,5.8,4.6,17.0,11.5,6.1,7.7,10.0,3.4,11.5,5.1,5.4,6.4,3.2,5.2,2.6,2.3,3.7,5.1,17.0,2.2,7.6,7.8,10.7,7.7,8.1,6.0,7.7,9.8,4.9,4.3,9.3,4.6,11.8,9.2,5.9,4.2,4.5,10.1,6.3,5.1,9.6,8.7,9.6,4.2,6.0,3.6,5.3,4.7,10.8,2.8,5.6,11.9,8.1,7.3,3.5,11.6,4.5,5.2,7.4,7.3,3.4,2.9,8.8,11.9,2.8,3.6,2.6,9.6,11.5,11.2,11.7,4.5,6.7,8.4,7.1,5.3,8.6,4.5,8.4,7.4,3.0,3.7,3.8,4.8,3.1,6.3,2.7,10.5,8.5,8.8,4.4,12.0,8.4,8.1,3.8,9.9,4.3,4.4,3.9,4.5,7.6,8.2,10.6,2.2,4.0,8.2,10.5,4.8,11.6,3.1,7.8,5.1,5.9,10.6,7.4,4.7,3.9,10.8,8.6,8.3,8.1,7.1,0.0,8.4,7.1,8.2,11.9,10.2,8.2,9.5,5.9,4.7,7.8,2.3,17.0,7.3,4.6,8.1,10.3,3.9,2.4,9.5,2.4,4.4,6.9,10.7,10.8,7.7,4.4,7.3,6.3,10.2,11.7,11.9,2.4,2.5,3.5,4.3,3.1,7.2,9.8,4.3,5.8,7.1,9.7,2.7,5.5,7.5,3.0,2.2,3.2,3.3,11.0,11.0,7.5,17.0,0.0,9.8,5.4,6.9,5.0,9.0,4.5,6.4,9.6,8.3,11.7,11.7,4.3,9.5,8.8,12.0,10.6,9.5,5.8,2.2,3.4,2.5,3.6,6.1,2.4,2.5,9.2,5.0,2.0,10.4,11.7,5.8,2.2,17.0,9.6,11.2,7.0,5.1,8.1,11.6,2.1,3.9,9.4,6.9,5.7,4.2,8.7,7.0,5.2,4.6,11.2,2.4,3.8,9.9,11.4,9.8,5.8,2.1,5.6,2.5,8.3,9.3,2.1,6.0,4.8,5.1,10.6,2.1,2.9,3.3,6.5,7.6,11.8,4.8,6.4,7.2,5.6,3.0,6.9,2.5,2.4,10.6,8.9,10.0,11.1,6.9,4.1,8.4,7.3,8.9,5.8,11.5,10.5,4.4,8.9,8.4,10.9,6.9,2.1,4.6,10.0,6.6,3.6,5.1,2.8,10.8,6.9,5.2,4.8,2.6,2.9,6.7,9.7,4.5,9.3,7.6,3.5,2.5,4.2,5.7,8.9,4.7,7.1,10.0,2.0,8.1,7.8,7.4,4.5,11.1,2.7,4.6,11.9,10.4,2.8,7.4,7.5,2.8,5.8,9.9,6.3,6.7,3.7,5.7,4.7,11.0,3.1,10.4,5.6,7.9,5.2,7.4,9.7,6.0,3.0,9.5,6.6,8.8,7.7,6.3,3.3,9.0,7.8,8.0,17.0,3.9,6.9,2.5,2.6,9.1,4.7,2.2,11.5,6.6,6.3,2.3,8.8,10.3,4.0,11.8,9.3,6.5,9.1,11.2,4.5,2.2,8.9,9.9,8.3,2.9,4.3,9.1,2.0,5.1,3.7,5.3,10.9,10.0,3.8,9.7,8.1,7.9,4.2,9.0,11.0,10.1,6.9,5.3,3.6,4.3,4.0,2.8,7.2,7.2,11.1,11.1,2.0,5.8,5.5,11.2,6.8,9.5,7.2,17.0,4.8,2.6,4.6,8.0,7.9,11.6,7.0,6.9,5.4,4.5,9.7,4.8,6.2,9.4,4.4,9.5,2.1,2.3,17.0,11.5,6.1,5.2,3.6,5.4,8.3,9.5,10.1,11.9,8.3,11.7,3.0,7.5,9.4,7.1,9.1,9.7,7.4,4.8,7.3,4.0,5.7,6.2,5.3,10.5,10.3,6.9,5.6,4.9,5.5,11.8,10.1,9.6,9.8,3.2,2.0,11.8,6.3,8.5,11.0,6.3,8.3,5.2,11.8,4.0,9.1,9.8,7.9,9.2,12.0,6.9,10.9,0.0,2.8,8.0,9.5,5.7,7.3,7.8,17.0,9.8,9.6,6.9,8.2,2.7,4.4,8.1,3.2,9.2,7.4,3.8,9.9,4.8,9.7,9.0,9.5,4.5,7.0,11.0,8.7,9.9,10.3,4.9,10.6,8.8,7.0,6.5,9.8,9.6,11.6,4.4,4.4,5.7,9.9,10.6,9.5,3.8,3.3,7.6,6.9,11.0,6.9,7.8,4.5,4.3,2.4,6.1,2.2,11.2,17.0,3.2,7.6,17.0,8.6,8.2,11.8,9.7,8.2,7.4,5.2,3.9,10.9,10.2,8.4,6.5,9.1,5.4,5.1,6.9,5.5,6.2,3.1,2.5,5.0,3.5,10.7,9.3,9.1,9.3,2.0,7.7,6.3,9.7,10.9,3.0,7.5,3.1,7.8,8.8,2.7,6.9,4.1,5.2,11.6,9.5,10.8,3.1,4.0,10.5,10.6,3.6,6.8,2.1,11.4,11.4,2.2,2.3,4.1,11.1,9.4,6.9,10.8,10.4,7.1,6.7,6.1,6.2,11.0,17.0,3.5,8.1,8.2,11.4,3.9,11.6,2.3,5.7,2.9,6.9,11.2,8.3,11.4,5.3,5.8,8.7,11.4,11.8,0.0,6.8,9.0,11.3,2.2,5.3,9.3,5.5,10.9,11.3,4.1,4.8,6.7,8.7,6.0,4.8,4.3,6.8,10.8,7.0,9.7,11.9,4.2,5.4,6.3,7.3,4.5,9.9,4.8,7.3,8.0,8.3,10.4,5.1,9.0,2.3,12.0,10.2,4.1,7.9,4.8,11.1,8.1,4.2,7.8, ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f668ea04-70cd-4ceb-af12-9612e52dc436" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f668ea04-70cd-4ceb-af12-9612e52dc436")) {                    Plotly.newPlot(                        "f668ea04-70cd-4ceb-af12-9612e52dc436",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sleep Duration (hrs)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#B07AA1","pattern":{"shape":""}},"name":"","nbinsx":25,"offsetgroup":"","orientation":"v","showlegend":false,"x":[8.9,1.3000000000000007,11.7,5.6,5.4,8.4,6.6,4.7,5.0,8.4,7.3,8.8,4.4,4.3,7.8,8.5,5.6,4.8,7.2,7.9,5.4,7.3,7.7,8.5,4.3,6.8,7.9,8.2,4.7,4.9,4.6,8.5,11.7,8.8,8.6,6.4,8.6,6.5,7.6,8.3,8.1,4.7,6.9,5.1,6.6,6.2,6.8,7.3,8.5,5.4,7.8,7.2,5.1,6.4,8.5,9.0,7.0,5.6,5.0,4.5,6.1,5.6,8.5,8.0,8.8,8.1,6.0,5.6,7.3,7.2,6.7,4.1,7.8,5.5,8.7,4.7,6.6,4.9,8.3,6.4,5.0,4.6,7.5,7.2,6.8,6.8,11.7,5.0,5.4,5.3,4.1,8.2,4.3,6.5,6.7,5.5,4.0,6.2,4.6,5.0,7.5,8.5,6.4,7.2,6.4,7.8,4.9,4.6,7.7,6.6,4.2,4.7,7.7,5.5,5.0,5.4,7.7,6.8,6.1,5.7,4.8,7.2,7.9,4.6,8.4,5.3,8.5,7.5,4.4,6.6,7.8,8.5,4.6,7.3,6.5,6.7,9.0,4.8,6.8,4.5,8.7,7.1,7.1,7.1,8.9,5.3,5.3,8.0,6.5,4.1,5.1,5.8,5.8,6.1,7.7,4.8,6.1,5.2,4.2,5.1,7.1,6.3,6.8,5.6,6.6,9.0,4.8,5.1,7.1,6.5,8.6,7.6,7.2,6.1,7.5,6.7,7.8,4.2,5.1,8.3,8.9,8.8,5.3,4.4,5.7,8.0,8.9,8.3,7.0,8.9,8.0,8.5,5.7,4.8,4.4,8.8,8.7,5.8,7.3,5.5,5.7,6.2,8.9,8.9,8.5,6.5,4.6,7.1,5.4,7.4,8.2,7.0,7.1,8.2,4.2,8.8,4.4,8.8,7.5,4.5,6.5,6.8,11.7,6.1,8.6,7.4,4.7,4.9,8.5,11.7,7.8,7.8,6.2,4.8,4.8,8.4,8.1,5.7,8.0,7.8,7.4,4.7,7.0,7.6,7.6,4.3,7.5,7.7,6.6,8.4,4.4,8.0,4.9,8.2,11.7,8.5,4.9,8.1,4.4,4.4,4.4,6.9,6.2,5.9,6.1,6.4,4.8,6.5,7.9,6.3,8.4,7.1,7.2,4.1,8.9,5.4,8.5,1.3000000000000007,8.2,6.4,5.6,8.7,4.3,6.8,4.2,5.3,5.1,6.4,6.5,4.1,6.1,6.5,7.8,8.4,5.0,5.2,4.0,4.6,8.5,6.8,6.3,8.3,6.0,5.9,5.0,7.0,7.6,8.3,4.5,7.8,8.7,5.4,7.5,5.3,8.2,7.2,8.3,4.8,7.9,4.5,5.7,11.7,4.1,7.8,6.4,5.5,5.2,6.9,8.3,8.1,6.8,6.8,5.4,4.2,6.8,4.6,5.8,5.2,4.8,8.0,8.8,4.6,7.4,8.6,8.3,6.7,6.5,7.1,5.8,5.9,4.4,6.9,1.3000000000000007,8.4,6.3,7.0,8.0,5.1,4.9,6.1,6.6,8.0,6.3,6.6,4.2,4.6,6.6,5.0,6.0,7.3,5.8,4.6,5.2,6.7,4.3,6.9,7.5,6.0,8.2,7.3,4.0,6.1,7.4,6.1,6.2,5.1,8.0,8.6,6.5,8.9,7.1,5.0,6.6,8.8,5.6,4.8,5.2,5.2,7.2,5.4,6.3,5.6,7.0,11.7,4.1,5.6,5.1,11.7,5.9,6.0,4.1,5.5,7.5,7.7,7.2,5.6,4.4,5.6,5.5,7.0,6.0,8.5,7.3,8.3,6.2,8.0,7.6,6.7,4.3,5.9,4.1,6.8,7.0,4.4,6.3,5.5,4.4,8.9,5.9,6.3,6.2,7.5,6.4,5.7,8.8,8.7,6.5,8.8,4.1,5.5,7.1,6.7,5.1,5.7,6.9,7.1,11.7,4.5,5.7,5.9,7.0,4.1,6.9,4.3,5.6,8.5,5.1,8.4,6.5,5.6,7.5,6.6,7.4,8.2,6.4,7.6,8.4,8.8,6.8,4.6,8.2,5.2,8.6,8.2,8.9,8.2,6.7,6.3,4.3,7.0,6.2,5.3,4.2,7.0,8.4,7.8,7.5,6.4,5.6,5.3,6.6,6.7,8.0,4.4,6.9,8.4,6.8,4.6,5.1,4.2,5.7,4.9,5.3,6.5,6.7,4.5,5.3,4.0,5.9,7.1,4.2,5.8,11.7,9.0,8.3,4.9,4.3,5.8,4.7,8.0,7.5,8.8,5.2,8.2,8.7,6.7,6.1,8.2,7.9,5.8,6.6,5.9,5.0,1.3000000000000007,7.8,7.9,7.2,8.6,8.0,4.0,1.3000000000000007,5.6,8.9,7.6,7.1,5.4,6.7,6.0,8.0,7.9,6.5,5.6,6.3,4.1,7.9,4.1,5.4,6.8,6.1,5.5,6.4,7.9,4.9,4.3,4.0,6.5,5.8,6.9,6.6,6.7,8.9,7.6,8.3,8.9,7.9,4.9,6.1,11.7,4.7,4.0,5.1,8.2,5.0,7.3,7.8,4.8,5.8,5.7,4.4,4.9,8.6,7.1,7.4,5.8,4.7,6.2,4.2,6.4,5.9,1.3000000000000007,5.5,7.4,8.5,6.8,6.5,6.1,4.4,6.9,6.9,4.4,4.5,5.6,4.6,7.3,4.8,8.7,7.0,6.8,8.9,5.4,8.1,5.4,5.1,5.9,5.6,5.2,8.9,5.2,4.7,4.3,8.1,4.6,6.5,7.2,4.0,5.6,7.5,5.6,5.8,6.0,6.5,4.7,8.9,7.6,8.8,7.1,7.6,4.3,7.5,6.5,6.5,7.0,4.4,6.3,5.2,8.8,5.5,6.3,7.7,7.9,8.3,4.3,7.6,4.2,6.8,7.1,4.1,6.0,5.3,6.1,4.6,7.4,7.7,8.4,7.9,5.1,6.6,5.1,5.7,8.2,6.4,8.2,7.9,8.2,7.0,9.0,7.9,7.2,4.6,8.2,6.0,4.4,9.0,5.4,4.1,4.2,11.7,5.1,6.1,4.6,4.8,4.1,6.5,4.7,6.6,11.7,7.9,4.8,4.6,7.1,8.2,4.6,8.3,5.6,5.0,8.9,6.5,4.6,4.6,8.0,4.1,7.2,6.1,8.0,7.3,7.1,6.4,7.2,8.5,4.2,7.7,4.3,4.2,4.6,5.5,6.6,7.6,6.2,8.5,6.1,4.9,8.7,4.4,8.9,5.9,8.6,4.8,7.4,6. ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2617bb23-262a-49e2-af21-e10936d3704c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2617bb23-262a-49e2-af21-e10936d3704c")) {                    Plotly.newPlot(                        "2617bb23-262a-49e2-af21-e10936d3704c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Physical Activity (hrs\u002fweek)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#B07AA1","pattern":{"shape":""}},"name":"","nbinsx":25,"offsetgroup":"","orientation":"v","showlegend":false,"x":[9.3,0.2,6.2,5.5,3.1,0.1,0.5,4.5,7.9,7.8,0.8,3.7,6.7,1.4,5.3,2.1,0.4,9.9,1.5,2.8,6.8,3.9,2.7,1.9,8.6,9.6,0.7,0.9,1.6,3.2,8.4,8.7,1.1,7.4,8.8,8.2,6.8,6.8,6.8,7.6,5.5,1.1,2.0,3.0,5.4,5.1,9.6,3.0,15.2,5.7,6.8,8.1,5.1,1.0,2.6,0.4,9.2,1.6,8.5,15.2,6.8,4.4,0.3,7.8,4.0,9.4,5.1,6.0,9.9,3.0,2.2,2.3,8.8,1.7,9.1,2.6,1.7,9.4,0.0,4.7,5.8,5.9,4.8,7.6,2.8,2.9,3.6,0.6,0.9,9.3,6.3,9.9,0.1,3.3,1.1,6.8,8.5,0.2,5.8,4.9,5.9,5.1,3.5,7.4,0.1,8.2,2.6,0.8,5.5,1.9,5.9,8.0,6.3,4.7,8.9,5.8,1.0,6.7,0.3,7.5,5.4,3.2,3.9,3.3,2.8,0.9,4.1,6.4,4.9,5.8,6.2,8.3,8.4,6.5,6.2,3.6,0.8,8.9,4.2,8.5,4.4,2.3,3.1,3.1,3.8,8.4,0.2,1.4,7.4,8.5,0.4,6.0,5.7,15.2,3.2,9.3,0.5,9.5,1.7,0.7,3.0,6.1,5.1,2.3,5.8,1.2,0.3,2.9,9.2,4.1,0.3,15.2,4.6,8.0,9.9,15.2,2.0,1.4,15.2,3.0,2.3,9.7,2.3,6.6,2.8,3.2,1.2,3.5,4.5,4.2,8.1,5.7,1.5,4.8,0.7,8.3,7.2,6.0,8.5,3.4,9.4,0.1,0.1,2.7,1.2,9.1,0.6,9.4,5.1,9.7,6.1,9.6,5.2,4.2,6.8,0.9,9.9,9.3,9.9,6.3,3.6,0.3,6.7,0.2,3.5,9.9,7.3,3.2,2.1,8.9,5.1,8.7,6.7,8.2,3.0,3.1,3.2,8.7,8.3,5.9,4.8,3.9,0.2,5.8,2.5,1.9,0.3,6.4,8.6,6.2,4.7,6.9,4.3,5.2,6.8,6.3,9.6,7.6,7.0,0.8,8.1,7.7,6.5,6.4,7.2,5.5,6.0,7.8,0.0,0.7,9.5,3.7,3.8,8.4,8.0,9.9,5.9,7.6,8.6,1.8,5.8,2.6,3.6,7.1,4.5,0.6,1.0,2.0,9.4,0.1,7.7,9.6,7.6,8.9,6.6,0.0,2.4,5.8,8.1,7.4,2.9,1.6,9.6,7.3,4.8,15.2,3.4,2.1,9.7,6.4,9.5,3.6,1.0,1.9,4.6,7.7,8.2,3.2,8.2,1.9,9.5,9.4,9.0,2.2,0.6,15.2,0.6,0.0,8.6,5.4,1.6,5.1,7.7,2.5,2.8,9.9,2.2,1.5,3.7,1.0,5.7,5.0,7.7,2.8,3.8,15.2,2.2,3.3,0.6,3.8,1.7,4.6,6.4,0.7,2.6,8.8,7.4,7.6,3.8,4.3,4.6,1.1,8.3,8.4,7.4,5.7,9.9,4.9,7.8,8.2,3.5,9.7,9.5,7.4,4.8,8.6,2.3,0.0,3.0,2.8,6.7,2.9,0.1,2.6,2.2,6.8,0.4,10.0,6.5,6.2,8.8,1.1,3.3,5.2,4.3,15.2,3.1,9.4,8.1,9.3,3.8,1.7,5.0,2.7,9.8,3.9,1.1,7.2,15.2,3.8,6.9,5.8,9.6,9.0,0.3,6.7,6.2,6.0,2.2,3.2,9.1,4.0,7.9,3.2,5.3,8.1,10.0,4.6,0.8,2.2,3.9,9.5,7.9,1.1,2.6,7.3,2.9,3.8,6.6,3.9,1.6,2.9,8.6,6.9,2.7,1.3,8.9,6.3,8.6,2.8,2.9,5.5,5.0,7.7,7.7,3.5,1.3,1.3,1.5,2.8,1.4,8.9,2.4,8.9,3.3,15.2,8.4,15.2,1.9,4.1,7.9,3.5,1.7,3.6,7.2,6.0,9.6,6.8,4.4,8.0,4.8,1.5,4.4,9.3,6.0,1.9,7.6,1.6,9.8,3.8,5.7,6.3,8.5,8.3,6.4,3.2,4.7,7.8,0.0,3.8,4.5,6.8,5.8,1.9,9.9,5.3,9.2,3.2,7.0,9.9,0.3,5.8,5.3,6.8,1.0,3.1,2.7,9.0,5.4,3.5,5.9,0.7,1.6,4.3,5.8,3.4,0.6,5.5,7.1,2.0,7.9,5.2,1.4,6.4,8.9,9.4,3.3,1.9,0.7,5.9,8.8,6.7,9.7,0.1,3.7,1.2,9.5,8.3,4.9,6.3,7.3,4.2,0.0,0.6,5.1,6.1,1.6,0.2,8.9,8.8,3.5,4.4,1.6,7.0,2.4,8.3,0.0,0.4,1.9,8.4,5.6,7.3,7.4,3.2,1.8,4.6,7.0,5.7,3.3,4.8,7.0,0.4,0.2,7.2,8.6,3.1,7.7,8.4,7.6,4.0,2.4,9.1,3.4,6.2,7.5,9.9,9.7,9.5,6.0,9.5,3.7,4.2,8.7,0.1,9.2,0.6,4.6,6.1,3.5,2.3,6.5,0.2,6.3,1.9,5.6,8.7,8.2,15.2,0.4,3.4,3.1,1.0,3.9,3.9,8.2,2.7,9.9,1.3,2.5,3.8,5.9,3.9,6.6,5.8,2.3,4.0,8.8,9.5,6.7,5.0,2.1,6.0,3.5,6.7,8.3,2.2,1.9,3.4,4.3,3.8,15.2,5.4,6.5,5.2,3.2,9.4,4.4,1.4,5.1,5.0,2.0,2.5,9.1,7.1,8.8,0.0,3.9,9.9,1.4,6.0,0.5,6.7,8.7,8.5,0.9,4.0,9.2,5.0,9.1,2.7,0.0,9.4,0.7,1.4,7.6,5.2,9.4,2.9,6.8,6.2,9.0,5.0,3.1,6.3,5.7,6.2,5.3,1.5,0.1,0.5,6.7,0.6,3.2,3.0,0.4,6.9,3.4,2.1,8.6,6.6,9.3,3.2,0.9,9.6,7.5,9.1,4.8,2.5,8.1,0.9,2.3,5.6,7.2,4.8,5.1,7.4,5.8,6.9,9.0,4.0,7.1,4.0,4.6,6.6,9.6,6.4,2.7,2.2,1.1,9.6,4.7,0.9,3.2,2.2,6.5,4.9,6.7,0.1,7.9,9.4,2.9,0.8,15.2,8.0,2.5,6.0,6.1,9.4,2.9,2.3,7.6,9.9,3.1,8.4,1.8,5.1,2.0,9.7,0.4,1.3,8.8,4.3,6.9,0.1,3.6,0.2,0.3 ...

# %% [markdown]
# # **Analisa Multivariate**

# %% [markdown]
# ## **Korelasi**

# %%
# Task D1 - Hitung korelasi
data_corr = df[df_numerik].corr()

# Tampilkan hasilnya
display(data_corr)
# Out:
#                                Age  Screen Time (hrs/day)  \
# Age                           1.00                   0.01
# Screen Time (hrs/day)         0.01                   1.00
# Sleep Duration (hrs)          0.02                  -0.00
# Physical Activity (hrs/week) -0.00                   0.02
#
#                               Sleep Duration (hrs)  \
# Age                                           0.02
# Screen Time (hrs/day)                        -0.00
# Sleep Duration (hrs)                          1.00
# Physical Activity (hrs/week)                 -0.02
#
#                               Physical Activity (hrs/week)
# Age                                                  -0.00
# Screen Time (hrs/day)                                 0.02
# Sleep Duration (hrs)                                 -0.02
# Physical Activity (hrs/week)                          1.00

# %%
import plotly.express as px

# Buat Grafiknya
fig = px.imshow(
    data_corr,
    color_continuous_scale='blues',
    title = '<b>Korelasi Kolom Numerik Data Student</b><br>',
    text_auto = True
)

#Menyembunyikan skala/rentang korelasi
fig.update_coloraxes(showscale=False)

#Atur judul heatmap
fig.update_layout(
    title = dict(
        x=0.5,
        y=0.9,
        xanchor='center',
        yanchor='top'
    ),
    width = 1000,
    height = 800
)

#Menampilkan heatmap
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="aa54d39d-00ea-4c03-b293-762f44b8ae1d" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa54d39d-00ea-4c03-b293-762f44b8ae1d")) {                    Plotly.newPlot(                        "aa54d39d-00ea-4c03-b293-762f44b8ae1d",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["Age","Screen Time (hrs\u002fday)","Sleep Duration (hrs)","Physical Activity (hrs\u002fweek)"],"y":["Age","Screen Time (hrs\u002fday)","Sleep Duration (hrs)","Physical Activity (hrs\u002fweek)"],"z":[[1.0,0.009628443235624933,0.01862527189297644,-0.0011593826664724166],[0.009628443235624933,1.0,-0.004056343152846302,0.018691996285429408],[0.01862527189297644,-0.004056343152846302,1.0,-0.019465995364903982],[-0.0011593826664724166,0.018691996285429408,-0.019465995364903982,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl" ...

# %% [markdown]
# # **Statistik tiap Kategori Academic Performance Change**

# %%
df.groupby(['Academic Performance Change']).agg(
    total_data = ('Name', 'count'),
    min_age = ('Age', 'min'),
    median_age = ('Age', 'median'),
    max_age = ('Age', 'max'),
    min_screen_time = ('Screen Time (hrs/day)', 'min'),
    median_screen_time = ('Screen Time (hrs/day)', 'median'),
    max_screen_time = ('Screen Time (hrs/day)', 'max'),
    min_sleep_duration = ('Sleep Duration (hrs)', 'min'),
    median_sleep_duration = ('Sleep Duration (hrs)', 'median'),
    max_sleep_duration = ('Sleep Duration (hrs)', 'max')
    )
# Out:
#                              total_data  min_age  median_age  max_age  \
# Academic Performance Change
# Declined                            310     8.00       20.00    32.00
# Improved                            317     8.00       21.00    32.00
# Same                                419     8.00       20.00    32.00
#
#                              min_screen_time  median_screen_time  \
# Academic Performance Change
# Declined                                0.00                6.90
# Improved                                0.00                7.00
# Same                                    0.00                6.90
#
#                              max_screen_time  min_sleep_duration  \
# Academic Performance Change
# Declined                               17.00                1.30
# Improved                               17.00                1.30
# Same                                   17.00                1.30
#
#                              median_sleep_duration  max_sleep_duration
# Academic Performance Change
# Declined                                      6.35               11.70
# Improved                                      6.50               11.70
# Same                                          6.60               11.70

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ## **Feature Selection**

# %%
# Copy DataFrame
data_preprocessing = df.copy()

# Hapus kolom name
data_preprocessing = data_preprocessing.drop(columns=['Name'])

# Tampilkan hasilnya
display(data_preprocessing.head())
# Out:
#    Gender   Age Education Level  Screen Time (hrs/day)  Sleep Duration (hrs)  \
# 0    Male 15.00         Class 8                   7.10                  8.90
# 1  Female 25.00             MSc                   3.30                  1.30
# 2    Male 20.00           BTech                   9.50                 11.70
# 3    Male 20.00              BA                  10.80                  5.60
# 4  Female 17.00        Class 11                   2.80                  5.40
#
#    Physical Activity (hrs/week) Stress Level Anxious Before Exams  \
# 0                          9.30       Medium                   No
# 1                          0.20       Medium                   No
# 2                          6.20       Medium                   No
# 3                          5.50         High                  Yes
# 4                          3.10       Medium                  Yes
#
#   Academic Performance Change
# 0                        Same
# 1                        Same
# 2                        Same
# 3                        Same
# 4                        Same

# %% [markdown]
# ## **Encoding**

# %%
# Definisikan ulang kolom kategorik dan kolom numerik
kolom_kategorik = data_preprocessing.select_dtypes(include=['object']).columns
kolom_numerik = data_preprocessing.select_dtypes(include=['number']).columns

# %%
# Import library yang dibutuhkan
from sklearn.preprocessing import OrdinalEncoder

# Panggil object Ordinal Encoder
ord_enc = OrdinalEncoder()

# Terapkan OrdinalEncoder ke kolom kategorik
data_preprocessing[kolom_kategorik] = ord_enc.fit_transform(data_preprocessing[kolom_kategorik])

# Tampilkan hasilnya
display(data_preprocessing.head())
# Out:
#    Gender   Age  Education Level  Screen Time (hrs/day)  Sleep Duration (hrs)  \
# 0    1.00 15.00             6.00                   7.10                  8.90
# 1    0.00 25.00             9.00                   3.30                  1.30
# 2    1.00 20.00             2.00                   9.50                 11.70
# 3    1.00 20.00             0.00                  10.80                  5.60
# 4    0.00 17.00             4.00                   2.80                  5.40
#
#    Physical Activity (hrs/week)  Stress Level  Anxious Before Exams  \
# 0                          9.30          2.00                  0.00
# 1                          0.20          2.00                  0.00
# 2                          6.20          2.00                  0.00
# 3                          5.50          0.00                  2.00
# 4                          3.10          2.00                  2.00
#
#    Academic Performance Change
# 0                         2.00
# 1                         2.00
# 2                         2.00
# 3                         2.00
# 4                         2.00

# %%
for col, categories in zip(kolom_kategorik, ord_enc.categories_):
    print(f"Mapping untuk \033[93m{col}\033[0m:\n")
    for i, cat in enumerate(categories):
        print(f"  {cat} → {i}")
    print()
# Out:
# Mapping untuk Gender:
#
#   Female → 0
#   Male → 1
#   Other → 2
#
# Mapping untuk Education Level:
#
#   BA → 0
#   BSc → 1
#   BTech → 2
#   Class 10 → 3
#   Class 11 → 4
#   Class 12 → 5
#   Class 8 → 6
#   Class 9 → 7
#   MA → 8
#   MSc → 9
#   MTech → 10
#   Unknown → 11
#
# Mapping untuk Stress Level:
#
#   High → 0
#   Low → 1
#   Medium → 2
#   Unknown → 3
#
# Mapping untuk Anxious Before Exams:
#
#   No → 0
#   Unknown → 1
#   Yes → 2
#
# Mapping untuk Academic Performance Change:
#
#   Declined → 0
#   Improved → 1
#   Same → 2

# %% [markdown]
# # **Splitting Data**

# %%
# Import library yang digunakan
from sklearn.model_selection import train_test_split

# Variabel X untuk fitur dan variabel y untuk target
X = data_preprocessing.drop(columns=['Academic Performance Change'])
y = data_preprocessing['Academic Performance Change']

# Proses splitting data
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.25,
    random_state=1
    )

# %%
# Tampilkan frekuensi kemunculan target
display(y_train.value_counts())
# Out:
# Academic Performance Change
# 2.00    315
# 0.00    245
# 1.00    232
# Name: count, dtype: int64

# %% [markdown]
# ## **Imbalance Target**

# %%
# Import library imblearn
from imblearn.over_sampling import SMOTE

# Buat object SMOTE
smote = SMOTE(random_state=1)

# Terapkan pada X_train dan X_test dan buat variabel baru hasil oversampling
X_train_resample, y_train_resample = smote.fit_resample(X_train, y_train)

# %%
# Tampilkan frekuensi kemunculan target
display(y_train_resample.value_counts())
# Out:
# Academic Performance Change
# 2.00    315
# 0.00    315
# 1.00    315
# Name: count, dtype: int64

# %% [markdown]
# # **Modelling**

# %%
from imblearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

pipeline = Pipeline(steps=[
    ('scaler', RobustScaler()),
    ('smote', SMOTE()),
    ('model',DecisionTreeClassifier())
])

param_grid = {
    'smote__k_neighbors': [3, 5, 7],
    'model__criterion': ['gini', 'entropy', 'log_loss'],
    'model__max_depth': [None, 5, 10, 20, 30],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 5],
    'model__class_weight': [None, 'balanced']
}

grid = GridSearchCV(
    estimator = pipeline,
    param_grid = param_grid,
    cv = 5,
    scoring = 'f1_macro',
    n_jobs = -1
)

grid.fit(X_train, y_train)

print("Best Params:", grid.best_params_)
print("Best CV Score:", grid.best_score_)
# Out:
# Best Params: {'model__class_weight': None, 'model__criterion': 'gini', 'model__max_depth': None, 'model__min_samples_leaf': 2, 'model__min_samples_split': 2, 'smote__k_neighbors': 7}
# Best CV Score: 0.3834442188869926

# %%
# Import library yang dibutuhkan
from sklearn.model_selection import StratifiedKFold, cross_val_score

# Masukan parameter yang telah di-tuning
model_dtc = DecisionTreeClassifier(
    criterion = 'entropy',
    max_depth = 30,
    min_samples_leaf = 1,
    min_samples_split = 5,
    splitter = 'best'
)

# Definsikan pipeline baru
new_pipe = Pipeline([
    ('scaler', RobustScaler()),
    ('smote', SMOTE()),
    ('model', model_dtc)
])

# Terapkan pada CV
cv = StratifiedKFold(
    n_splits = 5,
    shuffle = True,
    random_state = 42
)

scores = cross_val_score(new_pipe, X, y, cv=cv, scoring = 'accuracy')

print(f'Scores : {scores}')
print(f'Mean   : {scores.mean()}')
print(f'Std    : {scores.std()}')
# Out:
# Scores : [0.33962264 0.30331754 0.33649289 0.30331754 0.31753555]
# Mean   : 0.3200572297236878
# Std    : 0.015618770219810925

# %%
model_dtc.fit(X_train_resample, y_train_resample)

# Predict test set labels
y_pred = model_dtc.predict(X_test)

# %%
from sklearn import metrics

# Menghitung dan mencetak laporan klasifikasi
classification_report = metrics.classification_report(y_pred, y_test)

# Tampilkan hasilnya
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.27      0.31        89
#          1.0       0.34      0.36      0.35        83
#          2.0       0.37      0.43      0.40        92
#
#     accuracy                           0.36       264
#    macro avg       0.36      0.36      0.35       264
# weighted avg       0.36      0.36      0.35       264

# %%
import plotly.express as px
from sklearn.metrics import confusion_matrix

# Plot dengan Plotly
fig = px.imshow(
    confusion_matrix(y_test, y_pred),
    text_auto = True,
    color_continuous_scale = 'Blues',
    title = "<b>Confusion Matrix Model Decision Tree</b>",
)

# Ubah tampilan xticks dan yticks
fig.update_xaxes(
    tickmode = "array",
    tickvals = [0, 1, 2],
    ticktext = ['Declined', 'Improved', 'Same']
)

fig.update_yaxes(
    tickmode = "array",
    tickvals = [0, 1, 2],
    ticktext = ['Declined', 'Improved', 'Same'],
    tickangle = -90
)

# Hapus legend / colorbar
fig.update_layout(coloraxis_showscale = False)

# Judul dan label + ukuran figure
fig.update_layout(
    title = dict(
        x = 0.5,
        y = 0.9,
        xanchor = 'center',
        yanchor = 'top'
    ),
    xaxis_title = "<b>Prediksi</b>",
    yaxis_title = "<b>Nilai Sebenarnya</b>",
    width = 700,
    height = 700
)

# Tampilkan grafik
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="20920555-8ead-4385-9fba-7b8663ec7074" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20920555-8ead-4385-9fba-7b8663ec7074")) {                    Plotly.newPlot(                        "20920555-8ead-4385-9fba-7b8663ec7074",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","z":[[24,21,22],[28,30,30],[37,32,40]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker" ...
